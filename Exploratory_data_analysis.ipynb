# %% [markdown]
# # Exploratory Data Analysis (Prediction of Netflix movie rating)

# %% [markdown]
# **After data wrangling, the exploratory data analysis will be carried out on both Kaggle and IMDB datasets. Both datasets contain only movies.**

# %% [markdown]
# ### Import necessary Python packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Part - I:  Investigation into Kaggle Dataset

# %%
Kaggledata = pd.read_csv('clean_datafiles/mydata_movies_only.csv', index_col = 0)

# %%
Kaggledata.head()
# Out:
#   show_id   type  title                                               cast  \
# 1      s2  Movie   7:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2      s3  Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3      s4  Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4      s5  Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 6      s7  Movie    122  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
#
#          country  date_added  release_year rating  duration_min  \
# 1         Mexico        2016          2016  TV-MA            93
# 2      Singapore        2018          2011      R            78
# 3  United States        2017          2009  PG-13            80
# 4  United States        2020          2008  PG-13           123
# 6          Egypt        2020          2019  TV-MA            95
#
#                                            listed_in  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
# 6                Horror Movies, International Movies
#
#                                          description
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...
# 6  After an awful accident, a couple admitted to ...

# %%
Kaggledata.tail(3)
# Out:
#      show_id   type   title  \
# 7781   s7782  Movie    Zoom
# 7782   s7783  Movie    Zozo
# 7783   s7784  Movie  Zubaan
#
#                                                    cast  \
# 7781  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country  date_added  \
# 7781                                      United States        2020
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...        2020
# 7783                                              India        2019
#
#       release_year rating  duration_min  \
# 7781          2006     PG            88
# 7782          2005  TV-MA            99
# 7783          2015  TV-14           111
#
#                                            listed_in  \
# 7781              Children & Family Movies, Comedies
# 7782                    Dramas, International Movies
# 7783  Dramas, International Movies, Music & Musicals
#
#                                             description
# 7781  Dragged from civilian life, a former superhero...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...

# %%
Kaggledata.shape
# Out:
# (4761, 11)

# %%
Kaggledata.columns
# Out:
# Index(['show_id', 'type', 'title', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration_min', 'listed_in', 'description'],
#       dtype='object')

# %%
Kaggledata.dtypes
# Out:
# show_id         object
# type            object
# title           object
# cast            object
# country         object
# date_added       int64
# release_year     int64
# rating          object
# duration_min     int64
# listed_in       object
# description     object
# dtype: object

# %%
Kaggledata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4761 entries, 1 to 7783
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4761 non-null   object
#  1   type          4761 non-null   object
#  2   title         4761 non-null   object
#  3   cast          4761 non-null   object
#  4   country       4761 non-null   object
#  5   date_added    4761 non-null   int64
#  6   release_year  4761 non-null   int64
#  7   rating        4761 non-null   object
#  8   duration_min  4761 non-null   int64
#  9   listed_in     4761 non-null   object
#  10  description   4761 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 446.3+ KB

# %% [markdown]
# ## Drawing insights from each column of the dataset

# %% [markdown]
# We can see that, there are some columns like country, languge, listed_in or genre, actor ect with many unique values combined together in one row relating to one movie. To have an idea on total number of unique values and to carry out feature engineering, we need to seaparte them. For this, a function is defined below:

# %%
def column_details(dataset, col):
    Number_of_unique_values = dataset[col].nunique()
    arr1 = dataset[col].value_counts()
    arr2 = dataset[col].value_counts(normalize = True)
    arr3 = arr1.head(20)
    arr4 = arr2.head(20)
    return arr1, arr2, arr3, arr4

# %% [markdown]
# **There are different countries making films, some make in large number while some make very few.  So let us sort out the countries according to the movie numbers, normalize them and visualize in barplot.**

# %%
print('Number of movies in each country in Kaggle dataset')
print(column_details(Kaggledata, 'country')[0],"\n\n", column_details(Kaggledata, 'country')[1])
print("\n",column_details(Kaggledata, 'country')[1])
# Out:
# Number of movies in each country in Kaggle dataset
# United States                    1667
# India                             837
# United Kingdom                    163
# Canada                            106
# Egypt                              88
#                                  ...
# Soviet Union, India                 1
# United States, France, Mexico       1
# United States, Chile, Israel        1
# Spain, United States                1
# Ireland, Luxembourg, Belgium        1
# Name: country, Length: 539, dtype: int64
#
#  United States                    0.350137
# India                            0.175803
# United Kingdom                   0.034237
# Canada                           0.022264
# Egypt                            0.018484
#                                    ...
# Soviet Union, India              0.000210
# United States, France, Mexico    0.000210
# United States, Chile, Israel     0.000210
# Spain, United States             0.000210
# Ireland, Luxembourg, Belgium     0.000210
# Name: country, Length: 539, dtype: float64
#
#  United States                    0.350137
# India                            0.175803
# United Kingdom                   0.034237
# Canada                           0.022264
# Egypt                            0.018484
#                                    ...
# Soviet Union, India              0.000210
# United States, France, Mexico    0.000210
# United States, Chile, Israel     0.000210
# Spain, United States             0.000210
# Ireland, Luxembourg, Belgium     0.000210
# Name: country, Length: 539, dtype: float64

# %%
print('Country with maximum number of movies in Kaggle dataset:', column_details(Kaggledata, 'country')[0].idxmax(axis = 1))
# Out:
# Country with maximum number of movies in Kaggle dataset: United States

# %%
# Plot top 20 countries based on movie production
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(Kaggledata, 'country')[2].index, y = column_details(Kaggledata, 'country')[2].values)
plt.xticks(rotation = 90)
plt.xlabel('Country')
plt.ylabel('Number of movies')
plt.title("Country vs. Number of movies (Kaggle Dataset), top 20 countries")
plt.show()

# %% [markdown]
# **It shows, USA produced the maximum number of movies, India ranks second while United Kingdom in third place.**

# %% [markdown]
# **In different years, movies have been released. A detail investigation into this column is given below:**

# %%
print('The number of movies released in each year as listed in Kaggle dataset')
column_details(Kaggledata, 'release_year')[0], column_details(Kaggledata, 'release_year')[1]
# Out:
# The number of movies released in each year as listed in Kaggle dataset
# (2017    636
#  2018    628
#  2016    559
#  2019    482
#  2020    353
#         ...
#  1966      1
#  1942      1
#  1945      1
#  1964      1
#  1946      1
#  Name: release_year, Length: 71, dtype: int64, 2017    0.133585
#  2018    0.131905
#  2016    0.117412
#  2019    0.101239
#  2020    0.074144
#            ...
#  1966    0.000210
#  1942    0.000210
#  1945    0.000210
#  1964    0.000210
#  1946    0.000210
#  Name: release_year, Length: 71, dtype: float64)

# %%
print("The total number of listed years in which movies have been released : ", len(column_details(Kaggledata, 'release_year')[0].index))
print("The maximum number of movies released in the year: ", column_details(Kaggledata, 'release_year')[0].idxmax(axis = 1))
# Out:
# The total number of listed years in which movies have been released :  71
# The maximum number of movies released in the year:  2017

# %%
# Make bar plot of top 20 years based on the number of movies
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(Kaggledata, 'release_year')[2].index, y = column_details(Kaggledata, 'release_year')[2].values)
plt.xlabel('Release year')
plt.ylabel('Number of movies')
plt.title("Release Year vs. Number of movies (Kaggle Dataset), top 20 years")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Let us investigate into the movie "added_year" i.e year the movies have been added to Netflix.**

# %%
column_details(Kaggledata, 'date_added')[0], column_details(Kaggledata, 'date_added')[1]
# Out:
# (2019    1334
#  2020    1190
#  2018    1128
#  2017     735
#  2016     210
#  2021      76
#  2015      47
#  2014      15
#  2011      13
#  2013       6
#  2012       3
#  2009       2
#  2008       1
#  2010       1
#  Name: date_added, dtype: int64, 2019    0.280193
#  2020    0.249947
#  2018    0.236925
#  2017    0.154379
#  2016    0.044108
#  2021    0.015963
#  2015    0.009872
#  2014    0.003151
#  2011    0.002731
#  2013    0.001260
#  2012    0.000630
#  2009    0.000420
#  2008    0.000210
#  2010    0.000210
#  Name: date_added, dtype: float64)

# %%
# Plot the added_year vs number of movies
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(Kaggledata, 'date_added')[0].index, y = column_details(Kaggledata, 'date_added')[0].values)
plt.xlabel('Added year')
plt.ylabel('Number of movies')
plt.title('Duration of movies vs. Number of movies (Kaggle dataset), top 20 added years')
plt.xticks(rotation = 90)
plt.show()

# %%
print('The year with maximum number of movies in Kaggledata dataset:', column_details(Kaggledata, 'date_added')[0].idxmax(axis = 1))
# Out:
# The year with maximum number of movies in Kaggledata dataset: 2019

# %% [markdown]
# **Let us investigate into the movies' duration time in minutes**

# %%
column_details(Kaggledata, 'duration_min')[0]
# Out:
# 93     121
# 94     120
# 90     117
# 95     114
# 97     108
#       ...
# 190      1
# 194      1
# 214      1
# 15       1
# 203      1
# Name: duration_min, Length: 188, dtype: int64

# %% [markdown]
# #### **Distribution of duration of the movies in minutes**

# %%
# Plot all the data in the column to see the distribution of duration time
plt.figure(figsize = (12, 6))
sns.histplot(Kaggledata.duration_min, bins = 20)
plt.title('Distribution of movie duration in minutes, Kaggle Dataset')
plt.show()

# %%
# Plot first 20 duration times with maximum number of movies
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(Kaggledata, 'duration_min')[2].index, y = column_details(Kaggledata, 'duration_min')[2].values)
plt.xlabel('Duration of movies in minutes')
plt.ylabel('Number of movies')
plt.title('Duration of movies vs. Number of movies (Kaggle data), top 20 duration time')
plt.xticks(rotation = 90)
plt.show()

# %%
print("The maximum number of movies of duration: ", column_details(Kaggledata, 'duration_min')[0].idxmax(axis = 1), 'minutes')
print("The minimum number of movies of duration: ", column_details(Kaggledata, 'duration_min')[0].idxmin(axis = 1), 'minutes')
print('Maximum duration of the movie:', Kaggledata.duration_min.max(), 'minutes')
print('Minimum duration of the movie:', Kaggledata.duration_min.min(), 'minutes')
# Out:
# The maximum number of movies of duration:  93 minutes
# The minimum number of movies of duration:  191 minutes
# Maximum duration of the movie: 312 minutes
# Minimum duration of the movie: 8 minutes

# %% [markdown]
# **Let us investigate into the number of movies of different rated(PG, R, NR etc) categories.**

# %%
movie_rating = Kaggledata.rating.value_counts()

# %%
# Let us make plot of "rating" vs "number of movies"
plt.figure(figsize = (8, 6))
sns.barplot(x = movie_rating.index, y = movie_rating.values)
plt.xlabel('Rating')
plt.ylabel('Number of movies')
plt.title('Rating vs. Number of movies (Kaggle data)')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Let us investigate deep more into each categorical columns

# %% [markdown]
# To do this, let us define a function to see the total unique values into the categorical columns:

# %%
def list_unique_values_in_column(data_frame, column):
    df = data_frame[column].str.split(',')
    list1 = []
    for i in df:
        list1.extend(each.strip() for each in i)
#    list2 = sorted(set(list1))
    return set(list1), len(set(list1))

# %% [markdown]
# ### Types of movies

# %%
list_unique_values_in_column(Kaggledata, 'listed_in')
# Out:
# ({'Action & Adventure',
#   'Anime Features',
#   'Children & Family Movies',
#   'Classic Movies',
#   'Comedies',
#   'Cult Movies',
#   'Documentaries',
#   'Dramas',
#   'Faith & Spirituality',
#   'Horror Movies',
#   'Independent Movies',
#   'International Movies',
#   'LGBTQ Movies',
#   'Movies',
#   'Music & Musicals',
#   'Romantic Movies',
#   'Sci-Fi & Fantasy',
#   'Sports Movies',
#   'Stand-Up Comedy',
#   'Thrillers'},
#  20)

# %%
Kaggledata.columns
# Out:
# Index(['show_id', 'type', 'title', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration_min', 'listed_in', 'description'],
#       dtype='object')

# %%
list_unique_values_in_column(Kaggledata, 'cast')
# Out:
# ({'Gavin Brocker',
#   'Clemmie Dugdale',
#   'Garry Marshall',
#   'Shek Sau',
#   'Maurice Bryrne',
#   'Arda Taşarcan',
#   'Kane Hodder',
#   'Nanami Sakuraba',
#   'Shirley Henderson',
#   'Sara Sálamo',
#   'Simon Woods',
#   'Frank Whaley',
#   'Bette Midler',
#   'Man-Wai Wong',
#   'Sandy Barnett',
#   'Erkan Can',
#   'Gregório Duvivier',
#   'Helena Sujecka',
#   'Jacqueline Bisset',
#   'Shilpa Shetty',
#   'Esther Rolle',
#   'Chris Tucker',
#   'Barbora Mudrochova',
#   'Kunaal Roy Kapur',
#   'Mathias Minne',
#   'David Fridman',
#   'Asal Deen',
#   'Joey Lauren Adams',
#   'Natasa Dorcic',
#   'Henry Cavill',
#   'Ruth Wilson',
#   'Barbora Bobulova',
#   'Orkun Karagöz',
#   'Nayanthara',
#   'Craig Francis',
#   'Bridget Christie',
#   'Ronen Rubenstein',
#   'Hilary Rose',
#   'Antonia Thomas',
#   'Amanda Root',
#   'Leo Gregory',
#   'Corbin Timbrook',
#   'Kit Harington',
#   'Hans Martin Stier',
#   'Lyon Daniels',
#   'Macaulay Culkin',
#   'Klarke Pipkin',
#   'Lakha Lakhwinder Singh',
#   'Anand',
#   'AnnaSophia Robb',
#   'Eric Clapton',
#   'Chinmayee Mandlekar',
#   'Emma Booth',
#   'Walter Pidgeon',
#   'Miriam Margolyes',
#   'Mark Cirillo',
#   'Susan Lynch',
#   'Sourav Chakraborty',
#   'Benedict Cumberbatch',
#   'Mark Fredrichs',
#   'John Kottoly',
#   'Nancy Khoury',
#   'Catherine Jacob',
#   'T.J. Atoms',
#   'Karthika Muraleedharan',
#   'Indrajit Sinha',
#   'Sumit Suri',
#   'Ghassan Chemali',
#   'Mark Little',
#   'Shayan Munshi',
#   'John C. Reilly',
#   'Kenneth Mitchell',
#   'Vaughn Taylor',
#   'Lord Frank',
#   'Ridho Hafiedz',
#   'Rodrigo Sánchez Patiño',
#   'Ankush Choudhary',
#   'Chang Ting-hu',
#   'Alba Ribas',
#   'Deepak Tijori',
#   'Sumeet Nijhawan',
#   'Kayvan Novak',
#   'Henry Zaga',
#   'Wesley Morgan',
#   'Olivia Roush',
#   'Mary J. Blige',
#   'Erasmo Carlos',
#   'Mohan Agashe',
#   'Lina Tejeiro',
#   'Anna Raadsveld',
#   'David Koechner',
#   'Ahlam Al-Gritly',
#   'Karunas',
#   'Toru Sakurai',
#   'Lanuakam Ao',
#   'Sienna Bohn',
#   'Viraaj Modgill',
#   'James Sweeney',
#   'Jimmy Deshler',
#   'Yon González',
#   'Tutie Kirana',
#   'Aleksandar Seksan',
#   'Xian Lim',
#   'Valentijn Dhaenens',
#   'Alaina Huffman',
#   'Mann Patel',
#   'Mary Mara',
#   'Radhika Menon',
#   'Munish Makhija',
#   'Rosie Fellner',
#   'Patrick Bakoba',
#   'Anjali Jathar',
#   'I Sen-ho',
#   'Sharad Kelkar',
#   'Baek Yoon-sik',
#   'Janae Marie Kroczaleski',
#   'Michael Lott',
#   'Jang Dong-gun',
#   'Kabby Borders',
#   'Serenity Reign Brown',
#   'Analeigh Tipton',
#   'Anna Davel',
#   'Nicolas Cage',
#   'Dina Pathak',
#   'Hania Aamir',
#   'W. Ellington Felton',
#   'Ray Haratian',
#   'Barry John',
#   'Vandana Gupte',
#   'Nabila Ebeid',
#   'Ken Hung',
#   'Anthony Lister',
#   'JoeDon Rooney',
#   'Jagpal Singh Chahal',
#   'Niteesh Wadhwa',
#   'Jessica Taylor-Bearman',
#   'Samir Ghanem',
#   'Djenar Maesa Ayu',
#   'Austin Ramsey',
#   'Patience Ozokwor',
#   'Anthony Batarse',
#   'Vijay S. Kumar',
#   'Alex Brendemühl',
#   'Pepi Sonuga',
#   'Elena Cánepa',
#   'Sarah Geronimo',
#   'Julia Stiles',
#   'Rahmi Dilligil',
#   'Trevor Devall',
#   'Sarah Baldwin',
#   'Bing Pimental',
#   'Shamol Mawla',
#   'Goro Inagaki',
#   'Michael Bacall',
#   'Shilpa Shukla',
#   'Molly Shannon',
#   'Sean Kenin',
#   'Sharon Lawrence',
#   'Teyana Taylor',
#   'Rob Ramsay',
#   'Marc Rhys',
#   'Lindsay Crouse',
#   'Priyaa Lal',
#   'Majo Cardozo',
#   'Cameron Jebo',
#   'Kate Tsui',
#   'Tarryn Alberts',
#   'Manpneet Grewal',
#   'Aparna Upadhyay',
#   'Hoang Phuc Nguyen',
#   'Aditya Bhattacharya',
#   'Karla Souza',
#   'Dion Mucciacito',
#   'Steven Richens',
#   'Komal Gupta',
#   'Candace Cameron Bure',
#   'Michael Jeter',
#   'Linus Roache',
#   'Daniel Gimenez Cacho',
#   'Kiana Madeira',
#   'Tyler Young',
#   'Lee Dong-hwi',
#   'Lotte Verbeek',
#   'Lotfy Labib',
#   'Jimmy Castro',
#   'Michael Sands',
#   'Alexandra Daddario',
#   'Beau Bridges',
#   'Louis Fan',
#   'Maica Barroso',
#   'Lesley Sharp',
#   'Koichi Yamadera',
#   'Shridhar Watsar',
#   'Robin Dunne',
#   'Collette Wolfe',
#   'Chitra Lakshmanan',
#   'Yareli Arizmendi',
#   'Doğa Rutkay',
#   'Popetorn Soonthornyanakij',
#   'Arthur Aspaturian',
#   'Toru Okawa',
#   'Niamh Wilson',
#   'Ashwini Apte',
#   'Alex Calleja',
#   'Tejaswini Kolhapure',
#   'Eduardo Paxeco',
#   'Toni Gonzaga',
#   'Jai Courtney',
#   'Yugan Naidoo',
#   'Melanie Ebanks',
#   'Burcu Kara',
#   'Zamokuhle Nxasana',
#   'Maribel Verdú',
#   'Gabriele Ferzetti',
#   'D. Santosh',
#   'Shelley Long',
#   'Bruce Campbell',
#   'Colm Meaney',
#   'Mitchell Hope',
#   'David Robbins',
#   'Amy Smart',
#   'Alessia Cara',
#   'Maurice LaMarche',
#   'Kiyohiko Shibukawa',
#   'Arturo Ríos',
#   'Remo Greene',
#   'Elena Cotta',
#   'Maya Krishna Rao',
#   'Chavis Daniels',
#   'Mohammed El Sadaany',
#   'Takumi Saitoh',
#   'Alexander Conti',
#   'Ciaran Bermingham',
#   'Sainty Nelsen',
#   'David W. Thompson',
#   'Hannibal Buress',
#   'Pierre Cartonnet',
#   'Arlen Escarpeta',
#   'Tamer Hosny',
#   'Lena Wilczyńska',
#   'Monty Sharma',
#   'Molly Ryman',
#   'Yukiyoshi Ozawa',
#   'Julian Garner',
#   'Nicolas Wanczycki',
#   'Mikkel Boe Følsgaard',
#   'Bayyumi Fuad',
#   'Indrans',
#   'Youyi',
#   'Casey Affleck',
#   'Damon Wayans Jr.',
#   'Abbey Lee',
#   'Eric Duguil',
#   'Bilal Ashraf',
#   'Neet Chowdhary',
#   'Jen Tullock',
#   'Bob Clendenin',
#   'Udhay',
#   'Gershwyn Eustache Jnr',
#   'Adrian Edmondson',
#   'Connor Williams',
#   'Bérénice Marlohe',
#   'Jeannie Elias',
#   'Simone Bailly',
#   'Wu Ma',
#   'Wang Xiao Chen',
#   'Kurush Deboo',
#   'Kirstin Howell',
#   'Amrita Puri',
#   'Raj Singh Jhinger',
#   'Amari Avery',
#   'Erik Per Sullivan',
#   'Chasty Ballesteros',
#   'Figs Jackman',
#   'Luke LaFontaine',
#   'Martin Lawrence',
#   'Ashlyn Drummond',
#   'Walter Huston',
#   'Ayten Gökçer',
#   'Mamoudou Athie',
#   'John Rhys-Davies',
#   'Marcelo Médici',
#   'Joelle Rizk',
#   'Leonardo Boudreau',
#   'Michael Bisping',
#   'Petelo Sealeu',
#   'Lonny Price',
#   'Coco Chiarella',
#   'Ralph Palka',
#   'Rebecca Miller',
#   'Alex Neustaedter',
#   'Nassar',
#   'Colin McFarlane',
#   'Natasza Urbańska',
#   'Karen Fukuhara',
#   'Robert Klein',
#   'K.K. Raina',
#   'Lorenzo Lamas',
#   'Cristina Morán',
#   'Lindsay Torrance',
#   'Rajendra Sethi',
#   'Werner Herzog',
#   'John Gemberling',
#   'Demi Lovato',
#   'Marwan Kenzari',
#   'Mary Woronov',
#   'Joaquín Rapalini',
#   'Kate Mara',
#   'Olivia Cooke',
#   'Judah Nelson',
#   'Peter Gallagher',
#   'Shivam Patil',
#   'Bill Moyers',
#   'Veronica Hampson',
#   'Zayed Mohammed Mahmoud',
#   'January Jones',
#   'Enuka Okuma',
#   'Salli Saffioti',
#   'Edward',
#   'Sean "P. Diddy" Combs',
#   'Oscar Serrano',
#   'Jonny Quinn',
#   'Jay Pennison',
#   'Khaled El Nabawy',
#   'Yuko Miyamura',
#   'Valentin Merlet',
#   'Danny McBride',
#   'Masami Nagasawa',
#   'Paul Wall',
#   'Catherine Johnson',
#   'Vedabrata Rao',
#   'Adeolu Adefarasin',
#   'Menassa Fahmy',
#   'Saurabh Sachdeva',
#   'Sam Page',
#   'Bill Courtney',
#   'Mahira Khan',
#   'Gabriela de la Garza',
#   'Shivaji Guruvayoor',
#   'Kelly Sheridan',
#   'Fionna Hewitt-Twamley',
#   'Leonardo Cecchi',
#   'Lance Gross',
#   'Magi Avila',
#   'Harvind Raj',
#   'Theo Rossi',
#   'María Elena Olivares',
#   'Ashok Pathak',
#   'Tommy Yuen',
#   'Elijah Canlas',
#   'David Walton',
#   'Vanessa Marano',
#   'Ana Caetano',
#   'Itzik Cohen',
#   'Bob Odenkirk',
#   'Michelle Jenner',
#   'Fatima Sana Shaikh',
#   'Ophelia Lovibond',
#   'James Van Der Beek',
#   'Amerul Affendi',
#   'Lanette Ware',
#   'Kurt Cobain',
#   'Tyrone Benskin',
#   'Jacek Koman',
#   'Sky Sudberry',
#   'Lauren Lapkus',
#   'Noelle North',
#   'Dara Our',
#   'Chad L. Coleman',
#   'Alex Barnett',
#   'Albrecht Schuch',
#   'Nidal El Askhar',
#   'Grego Rossello',
#   'Connie Booth',
#   'Douglas Tait',
#   'Gilad Kahana',
#   'Jaloo',
#   'Jordi Vilasuso',
#   'Zawe Ashton',
#   'Amir Bashir',
#   'Jordan Hayes',
#   'Edgar Allan Guzman',
#   'Lili Harahap',
#   'Kamber Hejlik',
#   'Maia Morgenstern',
#   'Richard Gunn',
#   'Shama Deshpande',
#   'Marhoom Ahmad Bilal',
#   'Nandini Bora',
#   'Sanjeev Vats',
#   'Chelsea Kane',
#   'Lew Collins',
#   'Gina Riley',
#   'Sudeep',
#   'Emerald MacDonald',
#   'June Squibb',
#   'Jairo Ordóñez',
#   'Kazuhiro Muroyama',
#   'Mark Kubr',
#   'Aurélie Eliam',
#   'Amanda Nara',
#   "Nils d'Aulaire",
#   'Richard Ryan',
#   'Malena Alterio',
#   'Andrew Hefler',
#   'Zach De La Rocha',
#   'Tae-goo Eom',
#   'Laurence Breuls',
#   'Taner Birsel',
#   'Louise Grinberg',
#   'Clotilde Mollet',
#   'Nabila Ait Amer',
#   'Drew Barber',
#   'Mackenzie Crook',
#   'Jay Upadhyay',
#   'Paul Butler',
#   'Miriam Makeba',
#   'Rohan Chand',
#   'Meryl Streep',
#   "Ramblin' Jack Elliott",
#   'Aimee Teegarden',
#   'Karan Soni',
#   'Durga Khote',
#   'Chukwudi Iwuji',
#   'Nichelle Nichols',
#   'Rico Paris',
#   'Alessandro Cimadamore',
#   'Raline Shah',
#   'Jun Kunimura',
#   'Balachandran Chullikadu',
#   'Mark Cheng',
#   'Chung Ping Geung',
#   'John Cothran',
#   'Aabhas Yadav',
#   'Maudy Koesnaedi',
#   'Braedyn Bruner',
#   'Caledonia Burr',
#   'Derek Lee Nixon',
#   'Lawrence Makoare',
#   'Jens Hultén',
#   'Charlie Kelly',
#   'Kevin Rahm',
#   'Ai-Ai de las Alas',
#   'Manuela Pacq',
#   'Scott King',
#   'Reynold Hamzah',
#   'BrendaSykes',
#   'Munir Kabani',
#   'Chris Eigeman',
#   'Jisca Kalvanda',
#   'Swati Chitnis',
#   'Lorita Meg',
#   'Manya Gupta',
#   'Ashish Verma',
#   'Genezio de Barros',
#   'Jerzy Radziwiłowicz',
#   'Sean Hayes',
#   'Dillon Cavitt',
#   'Sarah Lancaster',
#   'Dermot Crowley',
#   'Jeet',
#   'Alexa Ilacad',
#   'Gerald Tyler',
#   'Judith Barsi',
#   'Wendi McLendon-Covey',
#   'Louis Herthum',
#   'Paul Michael Glaser',
#   'Henry Zebrowski',
#   'Qu Jingjing',
#   'Shaheizy Sam',
#   'Niranjani',
#   'John Malkovich',
#   'Lizze Broadway',
#   'Edi Gathegi',
#   'Natasha Liu Bordizzo',
#   'Pablo Schreiber',
#   'Harry Styles',
#   'Colin Donnell',
#   'Sun Li',
#   'Ronnie Quizon',
#   'David Calder',
#   'Alexander Strobele',
#   'Rajat Kaul',
#   'Laverne Cox',
#   'Madeleine Peters',
#   'Tanna Barthel',
#   'Didi Petet',
#   'Itziar Aizpuru',
#   'Teairra Mari',
#   'Shavinder Mahal',
#   'Tony Panterra',
#   'Hakan Eke',
#   'Peter Mel',
#   'Tom Hiddleston',
#   'Gaby Hoffmann',
#   'Jiang Yongbo',
#   'Maude Apatow',
#   'Joey Bishop',
#   'Mario Van Peebles',
#   'Mustafa Uzunyılmaz',
#   'Jean Smart',
#   'Eugen Knecht',
#   'Julian Glover',
#   'Adam Nourou',
#   'Cory Michael Smith',
#   'Richard Roxburgh',
#   'Olivia Newton-John',
#   'Kate Flannery',
#   'Nina Bergman',
#   'Vinoth Kishan',
#   'Adi Kvetner',
#   'Manikandan',
#   'Raphael Alejandro',
#   'Rebekah Graf',
#   'Sayed Sadek',
#   'Shannon Purser',
#   'Yoko Asagami',
#   'Zainab Balogun',
#   'Divya Rana',
#   'Addison Timlin',
#   'Charles Robinson',
#   'Biswanath Basu',
#   'Brynie Furstenberg',
#   'Emma Tate',
#   'Sophie Simnett',
#   'Luke Gordon',
#   'Vinnie Jones',
#   'Pierre Salvadori',
#   'Ethan Stiefel',
#   'Benjamin Charles Watson',
#   'Elisabeth Catherine Gray',
#   'Manpreet Singh',
#   'Donald Faison',
#   'Quinn Shephard',
#   'Harvey Guillen',
#   'John Lynch',
#   'Grant Show',
#   'Songül Öden',
#   'Giovanna Alparone',
#   'Matthew Mercer',
#   'Farid Shawqy',
#   'Robert G. Chiu',
#   'Nick Bateman',
#   'Michael Smiley',
#   'Will Patton',
#   'Vijay Babu',
#   'Jason Jones',
#   'Kiran Kumar',
#   'Yuri Chen',
#   'Ray Sahetapy',
#   'Jerry Minor',
#   'David Harbour',
#   'Andrey Dementiev',
#   'Sonia Dhillon',
#   'Lenny Kravitz',
#   'Bresha Webb',
#   'András Faragó',
#   'Julia Winter',
#   'Rupa Ganguly',
#   "Liam O'Brien",
#   'Michelle Phillips',
#   'Sifiso Ntuli',
#   'Denise Richards',
#   'Brian d’Arcy James',
#   'Payman Maadi',
#   'Christine Horne',
#   'Marco Leonardi',
#   'Keeley Hawes',
#   'Ken Erics',
#   'Nadia Lotfi',
#   'Massimo Popolizio',
#   'Pierre Lebeau',
#   'Dave Matthews',
#   'Brian Cox',
#   'Jeff Kober',
#   'Vinod Nagpal',
#   'Nadia Tueni',
#   'Ben Munoz',
#   'Stephanie Beatriz',
#   'Jeremy Blackman',
#   'Nobuo Tobita',
#   'Dong-won Gang',
#   'Sienna Miller',
#   'Aras Bulut İynemli',
#   'Pamela Jordán',
#   'Patricia Clarkson',
#   'Robert Mammone',
#   'Mick Jagger',
#   'Stephen Colbert',
#   'Michael Kenneth Williams',
#   'Brad Savage',
#   'Tony Leung Chiu-wai',
#   'Alice Lee',
#   'Cle Sloan',
#   'Vijay Deverakonda',
#   'Larry Miller',
#   'Kushalini Pulapa',
#   'Ariane Pellicer',
#   'E. Roger Mitchell',
#   'Tuba Büyüküstün',
#   'Daniela Duspara',
#   'Aparna Balamurali',
#   'Alan Young',
#   'Carey Westbrook',
#   'Mamoru Miyano',
#   'Alissa Latow',
#   'Necati Bilgiç',
#   'Timm Vladimir',
#   'Alan Tan',
#   'Ritika Singh',
#   'Carlos Macías',
#   'Li Guangjie',
#   'Steve Bacic',
#   'Hai Yu',
#   'Caroline Chaniolleau',
#   'Aadya Bedi',
#   'Cuba Gooding Jr.',
#   'Cameron Kennedy',
#   'Olivier Thouret',
#   'Balu Varghese',
#   'Abdur Arsyad',
#   'Brandon Miller',
#   'Jóhann Sigurðarson',
#   'Kerry Ingram',
#   'William Baldwin',
#   'Kate Nhung',
#   'Yves Flores',
#   'Beau DeMayo',
#   'Prim Bulakul',
#   'Phan Thanh Nhien',
#   'Aaron Glenane',
#   'Rakesh Varre',
#   'Arinzé Kene',
#   'Jocelyn Osorio',
#   'João Pedro Zappa',
#   'Gia Mantegna',
#   'Neha Sharma',
#   'Jane Kaczmarek',
#   'Carter Thicke',
#   'Mike Mitchell',
#   'Lucy Lawless',
#   'Ana Abad-Santos',
#   'Kim Chiu',
#   'Muskaan',
#   'David Letterman',
#   'Taylar Hender',
#   'Opal',
#   'Arjun Mathur',
#   'Peter Mensah',
#   'Loni Anderson',
#   'Jed Dy',
#   'Vicky Luengo',
#   'Sawsan Saad',
#   'EL',
#   'Evelyn Castro',
#   'Kiki Omeili',
#   'Sha Ine Febriyanti',
#   'Luis Bermejo',
#   'Daryl Gilley',
#   'Chin Chin Gutierrez',
#   'Trey Gondokusumo',
#   'Regina Spektor',
#   'Zhang Jiaming',
#   'Reggie Watts',
#   'Edgar Ramírez',
#   'Monica Dogra',
#   'Jerry Hauck',
#   'Yare Santana',
#   'Billy Drago',
#   'Lionel Messi',
#   'Retta',
#   'Patricio Castillo',
#   'Vasuki',
#   'Celso Bugallo',
#   'Ernest Ndhlovu',
#   'Sekoati Sk Tsubane',
#   'P.J. Gallagher',
#   'Emayatzy Corinealdi',
#   'Daman Singh',
#   'Babak Karimi',
#   'Aliyar',
#   'Rashid Khan',
#   'Olivia Merilahti',
#   'Steven Grayhm',
#   'Mansoor Alfeeli',
#   'Ciro Nacca',
#   'Theo James',
#   'Jessica Lu',
#   'Şinasi Yurtsever',
#   'Shalini Mohan',
#   'Jesse McCartney',
#   'Bobby Andrews',
#   'Robert Wagner',
#   'Gilbert Montoya',
#   'Trae Robin',
#   'Patricia Kihoro',
#   'Joe Billingiere',
#   'Vikram Grover',
#   'Maïwenn',
#   'Cruz Kim',
#   'Noma Dumezweni',
#   'Andree Vermeulen',
#   'Stephen Garlick',
#   'Chertsak Pratumseesakhon',
#   'Richard Brake',
#   'Ellen Barkin',
#   'Phoebe Robinson-Galvin',
#   'Huda Al Ghanim',
#   'Drew Barrymore',
#   'Shawn Faqua',
#   'Şebnem Bozoklu',
#   'Jake Lacy',
#   'Henry Winkler',
#   'Marco Baeza',
#   'Eva Link',
#   'Chinmay Kambli',
#   'Carl Lee',
#   'Rohan Mobarsa',
#   'Pisamai Pakdeevijit',
#   'Thomas Francis Murphy',
#   'Aftab Shivdasani',
#   'Arancha Martí',
#   'Roger Assaf',
#   'Piper Perabo',
#   'Kelsey Tucker',
#   'Johnny Massaro',
#   'Steven Dell',
#   'Jason Newman',
#   'John Vijay',
#   'Suzan Crowley',
#   'William Murray Weiss',
#   'Razor Ramon RG',
#   'Dennis Hayden',
#   'Kris Pearn',
#   'Burak Topaloglu',
#   'Hank Rogerson',
#   'Emily Ratajkowski',
#   'Wally Dunn',
#   'Sandra Ma',
#   'Simon Callow',
#   'Gustine Fudickar',
#   'Pierson Fode',
#   'Alice Belaïdi',
#   'Nick Ballard',
#   'Mark Adair-Rios',
#   'Angelina Jolie',
#   'Yuvika Chaudhry',
#   'Chia Yung Liu',
#   'Casey Simpson',
#   'Yi Long',
#   'Marco Aurélio Campos',
#   'Shery Adel',
#   'R.R. Melati Pinaring',
#   'Claudine Barretto',
#   'Kal Penn',
#   'Jacki Weaver',
#   'Tiger Shroff',
#   'Nitish Bharadwaj',
#   'Suman Mukhopadhyay',
#   'Carlos Chan',
#   'Parna Pethe',
#   'Ulrich Mühe',
#   'Kida Khodr Ramadan',
#   'Rex Lee',
#   'Giju John',
#   'Ash Chandler',
#   'Kumkum Chouhan',
#   'Amy Aitken',
#   'Vanessa Angel',
#   'Chris Gethard',
#   'Kerry Fox',
#   'Lorena Gale',
#   'Aishwarya Rai Bachchan',
#   'Ida Ursin-Holm',
#   'Sibabalwe Ngqayana',
#   'Umut Kurt',
#   'Ahmed Dash',
#   'Conrad Ricamora',
#   'Luichi Macías',
#   'Robin McLeavy',
#   'Sawsan Badr',
#   'Jonathan Slavin',
#   'Youssef Emalhoub',
#   'Jessica Pohly',
#   'Imogen Poots',
#   'Diaa El Merghany',
#   'Goutam Ghose',
#   'Munro Chambers',
#   'Bikram Chatterjee',
#   'Dede Satria',
#   'Müfit Can Saçıntı',
#   'Nathalie Emmanuel',
#   'Young-ae Kim',
#   'Emily Corcoran',
#   'Wale Adebayo',
#   'Ron Livingston',
#   'Anthony Wong Chau-Sang',
#   'Zhang Benyu',
#   'Salih Kalyon',
#   'Talat Hussain',
#   'João Côrtes',
#   'Zoe Kanters',
#   'Shaimaa Abdelkader',
#   'Rodrigo Guardiola',
#   'Sébastien Libessart',
#   'Eoin Macken',
#   'Madalina Anea',
#   'Varuth Waratham',
#   'Mary Holland',
#   'Ilia Kulik',
#   'Anjan Srivastav',
#   'Cymbal Byrd',
#   'Jerry Seinfeld',
#   'Tom Nowicki',
#   'O.T. Fagbenle',
#   'Shahana Goswami',
#   'Kirill Bichutsky',
#   'James Bloor',
#   'Lior Raz',
#   'Kelly Ward',
#   'Josh Charles',
#   'Claudia Ramírez',
#   'Gracy Soudi',
#   'Cloris Leachman',
#   'Antonio Dechent',
#   'Paolo Bernardini',
#   'Zoë Chao',
#   'Jacqueline Fernandez',
#   'Taline Stewart',
#   'Michael Perron',
#   'Kyeong-yeong Lee',
#   'Kirstie Alley',
#   'Bob Frazer',
#   'Razor Ramon HG',
#   'Rahul Gautam Sarma',
#   'Eddie Deezen',
#   'Jessica Serfaty',
#   'Saga Alyasery',
#   'Diana Bang',
#   'Nada Al Alfi',
#   'Michael deGruy',
#   'Yayaying Rhatha Phongam',
#   'Abdulmajeed Al-Ruhaidi',
#   'Eileen Heckart',
#   'Bigflo & Oli',
#   'Sophia Albarakbah',
#   'Mukesh Chhabra',
#   'Ragaa Hussein',
#   'Mark Griffin',
#   'Freida Pinto',
#   'Takako Matsu',
#   'Shaanthala',
#   'Shernaz Patel',
#   'Jessica Lindsey',
#   'Fehmi Karaarslan',
#   'Darren Mann',
#   'Hany El Sabagh',
#   'Cigano Satyohamba',
#   'Pauline Haddad',
#   'Manish Bhavan',
#   'Paintal',
#   'Haysen Percovich',
#   'Jarome Iginla',
#   'Gina Piersanti',
#   'Joshua Santana',
#   'Demian Aditya',
#   'Wojciech Bocianowski',
#   'Vincent Lindon',
#   'Rakeen Saad',
#   'Barbara Eve Harris',
#   'Sarah Jones',
#   'Dan Castellaneta',
#   'Taylour Paige',
#   'Mitch Silpa',
#   'Barbara King',
#   'Marilyn Norry',
#   'Kevin Nash',
#   'Peter Farrelly',
#   'Isabella Gomez',
#   'Ihana Dhillon',
#   'Daniel J. Travanti',
#   'Daniel Cooksley',
#   'Feng Shaofeng',
#   'Mary Jane Wells',
#   'Mahesh Manjrekar',
#   'Elnaaz Norouzi',
#   'Jowharah Jones',
#   'Ariel Vaysman',
#   'Xavier Samuel',
#   'Stephen Clinch',
#   'Ahmed Rizk',
#   'Sema Poyraz',
#   'Kanchana Moitra',
#   'Patricia Hodge',
#   'Owen Wilson',
#   'Teotola Maka',
#   'Kapil Jhaveri',
#   'Krishna Prabha',
#   'Roberto Leal',
#   'Esteban Lamothe',
#   'Bridgit Mendler',
#   'Richard Oh',
#   'Thomas Kretschmann',
#   'Stipe Erceg',
#   'Aiden Akpan',
#   'Pamela Nomvete',
#   'Prithvik Pratap',
#   'Vahldin Prelic',
#   'Alfonso Bassave',
#   'Got7',
#   'Cody Longo',
#   'Phillipa Soo',
#   'Will Forte',
#   'Roy Armstrong',
#   'Alejandro Patiño',
#   'Georges Corraface',
#   'Aml Ameen',
#   'Zhaohua Lu',
#   'Gaspard Schlatter',
#   'Joaquín Núñez',
#   'Hyper BB',
#   'Richard Libertini',
#   'Zhang Xiaolong',
#   'Hal Williams',
#   'Susumu Chiba',
#   'Alfonso Freeman',
#   'Chris Hardwick',
#   'Karina Smirnoff',
#   'Logan Shroyer',
#   'Sandip Pathak',
#   'Anoop Aravindan',
#   'Victor Gojcaj',
#   'ELSIE',
#   'Ruben Santiago-Hudson',
#   'Alex MacNicoll',
#   'Ali Rizvi',
#   'Julia Garner',
#   'Norm MacDonald',
#   'Tovino Thomas',
#   'Nithyasri Goru',
#   'Cory Oliver',
#   'Roger Craig Smith',
#   'Cristobal Tapia Montt',
#   'Davika Hoorne',
#   'AJ Bowen',
#   'Glenn Close',
#   'Boots Anson-Roa',
#   'Romain Duris',
#   'Brent Briscoe',
#   'Louis Ozawa Changchien',
#   'Anisa Rahma',
#   'Taylor Richardson',
#   'Gautam Gulati',
#   'O.J. Simpson',
#   'Rahul Kumar',
#   'Clara Wong',
#   'Neal McDonough',
#   'Shawn Wayans',
#   'Ewan McGregor',
#   'Oguzhan Kocakli',
#   'Tigmanshu Dhulia',
#   'Sho Ikushima',
#   'Brynna Drummond',
#   'Imelda Therinne',
#   'Shivani Bhai',
#   'Robert Racki',
#   'Michael Stahl-David',
#   'Lancelot Perrin',
#   'Paige Meade',
#   'José Dumont',
#   'Bobby Deol',
#   'Vipin Sharma',
#   'T.J. Storm',
#   'Tom Pelphrey',
#   'Hui Shiu Hung',
#   'Hassan Hosny',
#   'Tamer Hassan',
#   'Wilford Brimley',
#   'Nicole Ari Parker',
#   'Joe Gnoffo',
#   'Jake Epstein',
#   'Sunny Kaushal',
#   'Masahiko Tsugawa',
#   'Emilija Baranac',
#   'Kim Guk-hee',
#   'Shirley Setia',
#   'Bayray McNwizu',
#   'Dennis Bartok',
#   'Josh Ryan Evans',
#   'Kathy Murphy',
#   'Jon Kortajarena',
#   'Draya Michele',
#   'Anang Desai',
#   'Anisha Victor',
#   'Pedro Alonso',
#   'Steve Schirripa',
#   'François Bredon',
#   'Pitchawat Petchayahon',
#   'David Carradine',
#   'Kishore Kumar G.',
#   ...},
#  22622)

# %% [markdown]
# # Part-II: IMDB dataset

# %%
IMDBdata = pd.read_csv('clean_datafiles/IMDB_Movies_cleaned.csv', index_col = 0)
IMDBdata.head(2)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   imdb_title_id               original_title  year                    genre  \
# 0     tt0000009                   Miss Jerry  1894                  Romance
# 1     tt0000574  The Story of the Kelly Gang  1906  Biography, Crime, Drama
#
#    duration    country language         director           writer  \
# 0        45        USA     None  Alexander Black  Alexander Black
# 1        70  Australia     None     Charles Tait     Charles Tait
#
#            production_company  \
# 0  Alexander Black Photoplays
# 1              J. and N. Tait
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
#
#                                          description  avg_vote  votes  \
# 0  The adventures of a female reporter in the 1890s.       5.9    154
# 1  True story of notorious Australian outlaw Ned ...       6.1    589
#
#    reviews_from_users
# 0                 1.0
# 1                 7.0

# %%
IMDBdata.shape
# Out:
# (72043, 15)

# %%
IMDBdata.columns
# Out:
# Index(['imdb_title_id', 'original_title', 'year', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'reviews_from_users'],
#       dtype='object')

# %%
IMDBdata.dtypes
# Out:
# imdb_title_id          object
# original_title         object
# year                   object
# genre                  object
# duration                int64
# country                object
# language               object
# director               object
# writer                 object
# production_company     object
# actors                 object
# description            object
# avg_vote              float64
# votes                   int64
# reviews_from_users    float64
# dtype: object

# %%
IMDBdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72043 entries, 0 to 85851
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   imdb_title_id       72043 non-null  object
#  1   original_title      72043 non-null  object
#  2   year                72043 non-null  object
#  3   genre               72043 non-null  object
#  4   duration            72043 non-null  int64
#  5   country             72043 non-null  object
#  6   language            72043 non-null  object
#  7   director            72043 non-null  object
#  8   writer              72043 non-null  object
#  9   production_company  72043 non-null  object
#  10  actors              72043 non-null  object
#  11  description         72043 non-null  object
#  12  avg_vote            72043 non-null  float64
#  13  votes               72043 non-null  int64
#  14  reviews_from_users  72043 non-null  float64
# dtypes: float64(2), int64(2), object(11)
# memory usage: 8.8+ MB

# %% [markdown]
# **Here, "year" column is "Object" i.e string. So further investigation is needed and change column to integer type.**

# %%
IMDBdata2_year = pd.Series(IMDBdata.year)
print(set(IMDBdata2_year))
# Out:
# {'1984', '1970', '2001', '1974', '1982', '2012', '1971', '2017', '2006', 'TV Movie 2019', '2014', '2019', '2015', '1997', '1994', '2000', '1979', '1998', '2018', '2016', '2020', '2007', 1894, 1906, '2011', 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, '1999', '2013'}

# %% [markdown]
# **Here, one can see that one value is 'TV Movie 2019', therefore dtype of that column is showing "Object". So it needs to be converted to integer.**

# %%
# Let us see the row containing 'TV Movie 2019'
IMDBdata[IMDBdata['year'] =='TV Movie 2019']
# Out:
#       imdb_title_id original_title           year                     genre  \
# 83917     tt8206668  Bad Education  TV Movie 2019  Biography, Comedy, Crime
#
#        duration country language     director                        writer  \
# 83917       108     USA  English  Cory Finley  Mike Makowsky, Robert Kolker
#
#       production_company                                             actors  \
# 83917          HBO Films  Hugh Jackman, Ray Romano, Welker White, Alliso...
#
#                                              description  avg_vote  votes  \
# 83917  The beloved superintendent of New York's Rosly...       7.1  23973
#
#        reviews_from_users
# 83917               135.0

# %%
# Let us replace the "TV Movie 2019" to "2019"
# Then see how many years are there listed in the dataset and arrange them in ascending order
IMDBdata.replace({'year': {'TV Movie 2019' : '2019'}}, inplace = True)
IMDBdata2_year = pd.Series(IMDBdata.year)

year2 = []

for k in IMDBdata2_year:
    year2.append(int(k))
IMDBdata.year = year2

print(sorted(set(year2)),"\n")
print(len(sorted(set(year2))))
# Out:
# [1894, 1906, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
#
# 112

# %% [markdown]
# ### Insight from "country" column

# %%
# To draw insight from the "country" column, the previously defined function "column_details()" was used
column_details(IMDBdata, 'country')[0], column_details(IMDBdata, 'country')[1]
# Out:
# (USA                                26552
#  India                               4419
#  UK                                  3869
#  France                              2650
#  Japan                               2484
#                                     ...
#  Italy, Philippines, India              1
#  UK, USA, South Africa, Germany         1
#  France, Belgium, Germany, Haiti        1
#  Czech Republic, Slovenia               1
#  USA, Romania, Netherlands              1
#  Name: country, Length: 4507, dtype: int64,
#  USA                                0.368558
#  India                              0.061338
#  UK                                 0.053704
#  France                             0.036784
#  Japan                              0.034479
#                                       ...
#  Italy, Philippines, India          0.000014
#  UK, USA, South Africa, Germany     0.000014
#  France, Belgium, Germany, Haiti    0.000014
#  Czech Republic, Slovenia           0.000014
#  USA, Romania, Netherlands          0.000014
#  Name: country, Length: 4507, dtype: float64)

# %%
# Plot top 20 countries in movie production
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(IMDBdata, 'country')[2].index, y = column_details(IMDBdata, 'country')[2].values)
plt.xticks(rotation = 90)
plt.xlabel('Country')
plt.ylabel('Number of movies')
plt.title("Country vs. Number of movies (IMDB Dataset)")
plt.show()

# %%
# Plot top 20 countries in movie production
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(IMDBdata, 'country')[3].index, y = column_details(IMDBdata, 'country')[3].values)
plt.xticks(rotation = 90)
plt.xlabel('Country', fontdict = {'fontsize': 20 })
plt.ylabel('Number of movies', fontdict = {'fontsize': 20 })
plt.title("Top 20 countries in movie production", fontdict = {'fontsize': 20 })
plt.show()

# %% [markdown]
# **This dataset also(like Kaggele Dataset) show USA produced maximum number of movies, India ranks second while United Kingdom in third place.**

# %% [markdown]
# ### Insight into "year" column

# %%
print('The number of movies released in each year as listed in IMDBdata dataset')
column_details(IMDBdata, 'year')[0], column_details(IMDBdata, 'year')[1]
# Out:
# The number of movies released in each year as listed in IMDBdata dataset
# (2017    2621
#  2018    2614
#  2016    2500
#  2015    2353
#  2014    2314
#          ...
#  1913      10
#  1912       4
#  1894       1
#  1911       1
#  1906       1
#  Name: year, Length: 112, dtype: int64, 2017    0.036381
#  2018    0.036284
#  2016    0.034701
#  2015    0.032661
#  2014    0.032120
#            ...
#  1913    0.000139
#  1912    0.000056
#  1894    0.000014
#  1911    0.000014
#  1906    0.000014
#  Name: year, Length: 112, dtype: float64)

# %%
# During Corona pandemic, How many movies are released in 2019 and 2020
movies_2019 = IMDBdata[IMDBdata['year'] == 2019]
print("Number of movies released in 2019", movies_2019.year.count())


movies_2020 = IMDBdata[IMDBdata['year'] == 2020]
print("Number of movies released in 2020", movies_2020.year.count())
# Out:
# Number of movies released in 2019 2221
# Number of movies released in 2020 628

# %%
# Plot "Release Year vs Number of movies" from IMDB data
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(IMDBdata, 'year')[2].index, y = column_details(IMDBdata, 'year')[2].values)
plt.xlabel('Release year')
plt.ylabel('Number of movies')
plt.title("Release Year vs. Number of movies (IMDB data), top 20 release years")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Investigation into the movies' duration time in minutes

# %%
column_details(IMDBdata, 'duration')[0], column_details(IMDBdata, 'duration')[1]
# Out:
# (90     4172
#  95     2661
#  100    2566
#  92     2084
#  93     2029
#         ...
#  485       1
#  421       1
#  357       1
#  293       1
#  319       1
#  Name: duration, Length: 257, dtype: int64, 90     0.057910
#  95     0.036936
#  100    0.035618
#  92     0.028927
#  93     0.028164
#           ...
#  485    0.000014
#  421    0.000014
#  357    0.000014
#  293    0.000014
#  319    0.000014
#  Name: duration, Length: 257, dtype: float64)

# %%
# Plot for 20 top movie duration
plt.figure(figsize = (8, 6))
sns.barplot(x = column_details(IMDBdata, 'duration')[2].index, y = column_details(IMDBdata, 'duration')[2].values)
plt.xlabel('Duration (minutes)', fontdict = {'fontsize': 20})
plt.ylabel('count', fontdict = {'fontsize': 20})
plt.title('Duration of movies (IMDB dataset)', fontdict = {'fontsize': 20})
plt.xticks(rotation = 90)
plt.show()

# %%
print("Maximum movie length:", IMDBdata.duration.max())
print("Minimum movie length:", IMDBdata.duration.min())
# Out:
# Maximum movie length: 808
# Minimum movie length: 41

# %%
# See the deails of the maximum length movie
IMDBdata2 = IMDBdata[IMDBdata.duration == 808]
IMDBdata2
# Out:
#       imdb_title_id original_title  year                    genre  duration  \
# 85057     tt9047474        La flor  2016  Drama, Fantasy, Musical       808
#
#          country                                           language  \
# 85057  Argentina  Catalan, Spanish, French, English, Russian, Ge...
#
#              director          writer production_company  \
# 85057  Mariano Llinás  Mariano Llinás    El Pampero Cine
#
#                                                   actors  \
# 85057  Elisa Carricajo, Valeria Correa, Pilar Gamboa,...
#
#                                              description  avg_vote  votes  \
# 85057  A film in six episodes, connected by the same ...       7.7    473
#
#        reviews_from_users
# 85057                 5.0

# %%
# see the details of the minimum length movie
IMDBdata3 = IMDBdata[IMDBdata.duration == 41]
IMDBdata3
# Out:
#       imdb_title_id  original_title  year                         genre  \
# 32798     tt0142235  Doragon bôru Z  1989  Animation, Action, Adventure
#
#        duration country  language        director  \
# 32798        41   Japan  Japanese  Daisuke Nishio
#
#                              writer production_company  \
# 32798  Akira Toriyama, Takao Koyama     Toei Animation
#
#                                                   actors  \
# 32798  Masako Nozawa, Toshio Furukawa, Hiromi Tsuru, ...
#
#                                              description  avg_vote  votes  \
# 32798  In order to wish for immortality and avenge hi...       7.0   6042
#
#        reviews_from_users
# 32798                17.0

# %%
plt.figure(figsize = (18, 6))
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.hist(Kaggledata.duration_min, bins = 10)




ax2.hist(IMDBdata.duration, bins = 10)
plt.show()

# %% [markdown]
# ### **Distribution of the USA movies duration in minutes**

# %%
USA_movie_duration_IMDB = IMDBdata[IMDBdata.country == 'USA']['duration']

# %%
plt.figure(figsize = (8,6))
sns.histplot(USA_movie_duration_IMDB, bins = 10)
plt.title('Duration of USA movies',fontdict = {'fontsize': 20})
plt.xlabel('Duration (minutes)', fontdict = {'fontsize': 20})
plt.ylabel('Count', fontdict = {'fontsize': 20})
plt.show()

# %% [markdown]
# ### **Distribution of the Indian movies duration in minutes**

# %%
India_movie_duration_IMDB = IMDBdata[IMDBdata.country == 'India']['duration']

# %%
plt.figure(figsize = (8,6))
sns.histplot(India_movie_duration_IMDB, bins = 10)
plt.title('Duration of Indian movies (minutes)',fontdict = {'fontsize': 20})
plt.xlabel('Duration (minutes)', fontdict = {'fontsize': 20})
plt.ylabel('Count', fontdict = {'fontsize': 20})
plt.show()

# %% [markdown]
#  ### **Distribution of the UK movies duration in minutes**

# %%
UK_movie_duration_IMDB = IMDBdata[IMDBdata.country == 'UK']['duration']
UK_movie_duration_IMDB.shape
# Out:
# (3869,)

# %%
UK_movie_duration_IMDB2 = IMDBdata[IMDBdata.country == 'United Kingdom']['duration']
UK_movie_duration_IMDB2.shape
# Out:
# (0,)

# %%
plt.figure(figsize = (8,6))
sns.histplot(UK_movie_duration_IMDB, bins = 10)
plt.title('Duration of UK movies',fontdict = {'fontsize': 20})
plt.xlabel('Duration (minutes)', fontdict = {'fontsize': 20})
plt.ylabel('Count', fontdict = {'fontsize': 20})
plt.show()

# %% [markdown]
# ##  Investigation into director column of IMDB data

# %%
IMDB_USA_director = IMDBdata[IMDBdata['country'] == 'USA']['director']
IMDB_USA_director.value_counts().head(20)
# Out:
# Michael Curtiz        82
# Lesley Selander       77
# Lloyd Bacon           73
# William Beaudine      64
# Gordon Douglas        63
# Richard Thorpe        62
# John Ford             59
# Mervyn LeRoy          59
# Norman Taurog         56
# Joseph Kane           53
# Raoul Walsh           52
# Alfred E. Green       52
# William A. Seiter     51
# William A. Wellman    51
# George Marshall       50
# Lew Landers           48
# Roy Del Ruth          48
# Ray Enright           48
# George Sherman        46
# Henry Hathaway        46
# Name: director, dtype: int64

# %%
IMDB_Ind_director = IMDBdata[IMDBdata['country'] == 'India']['director']
IMDB_Ind_director
# Out:
# 2514     Vishnupant Govind Damle, Sheikh Fattelal
# 5736                                   Raj Kapoor
# 6072                                 Mehboob Khan
# 6082                                   Raj Kapoor
# 6233                                 Kamal Amrohi
#                            ...
# 85823                                 Vyasan K.P.
# 85828                              Vijith Nambiar
# 85843                            Lokesh Kanagaraj
# 85844                             Aswani Kumar V.
# 85847                                         Zam
# Name: director, Length: 4419, dtype: object

# %%
IMDB_Ind_director.value_counts().head(20)
# Out:
# Ram Gopal Varma                                        38
# David Dhawan                                           37
# Priyadarshan                                           32
# Mahesh Bhatt                                           27
# Satyajit Ray                                           25
# Vikram Bhatt                                           24
# Puri Jagannadh                                         21
# Mani Ratnam                                            20
# Hrishikesh Mukherjee                                   19
# Yash Chopra                                            18
# Rituparno Ghosh                                        16
# Shyam Benegal                                          16
# Srijit Mukherji                                        15
# Gautham Menon                                          15
# Abbas Alibhai Burmawalla, Mastan Alibhai Burmawalla    15
# Shakti Samanta                                         14
# K.S. Ravikumar                                         14
# Rajkumar Santoshi                                      14
# Anurag Kashyap                                         14
# S. Shankar                                             13
# Name: director, dtype: int64

# %%
IMDB_UK_director = IMDBdata[IMDBdata['country'] == 'UK']['director']
IMDB_UK_director.value_counts().head(20)
# Out:
# Gerald Thomas           39
# Ralph Thomas            34
# Terence Fisher          30
# Basil Dearden           29
# Val Guest               28
# Anthony Asquith         22
# Lewis Gilbert           22
# John Gilling            22
# Ken Annakin             22
# Roy Ward Baker          21
# Alfred Hitchcock        21
# Freddie Francis         20
# Carol Reed              19
# Marcel Varnel           17
# J. Lee Thompson         16
# Andrew Jones            16
# John Paddy Carstairs    16
# Michael Anderson        15
# Herbert Wilcox          15
# Lance Comfort           15
# Name: director, dtype: int64

# %%
IMDBdata.columns
# Out:
# Index(['imdb_title_id', 'original_title', 'year', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'reviews_from_users'],
#       dtype='object')

# %%
list_unique_values_in_column(IMDBdata, 'writer')
# Out:
# ({'Annelise Meineche',
#   'Sung-min Lee',
#   'Chase Hunter',
#   'Garry Marshall',
#   'Bruce A. Evans',
#   'Boon Collins',
#   'Young-hoon Park',
#   'Paul Naschy',
#   'Beatrice Ravaglioli',
#   'Michel Grisolia',
#   'Matej Bor',
#   'Jason Sherman',
#   'Edwin Brown',
#   'Joe Ahearne',
#   'Tajuddin Syed',
#   'Leo Chu',
#   'Gaby Dellal',
#   'Nathan Crooker',
#   'Pavan Kumar',
#   'Rob George',
#   'Albert Riéra',
#   'Alfred Uhry',
#   'James Gregory Kingston',
#   'Sang-hyon Lee',
#   'Frank Whaley',
#   'Georges Neveux',
#   'Brad Palmer',
#   'Wolfram Fleischhauer',
#   'Isil Özgentürk',
#   'Jerry Abrahamson',
#   'Riri Riza',
#   'L.H. Whittemore',
#   'James Morris',
#   'Diego Azulay',
#   'Guy Debord',
#   'Elliott Phear',
#   'Geoffrey Orthwein',
#   'Antoine Blondin',
#   'Chiho Saitô',
#   'Helen Lesnick',
#   'Daryush Shokof',
#   'Chase Mohseni',
#   'Bill Berry',
#   'Melanie Anne Phillips',
#   'Osman Ali',
#   'James MacManus',
#   'Craig Patrick',
#   'Scott Roberts',
#   'Sandra Bohle',
#   'Michael Lehmann',
#   'Joey Lauren Adams',
#   'Cliff Green',
#   'Praful Parekh',
#   'Johan Bogaeus',
#   'Oriol Capel',
#   'John Penney',
#   'Ryan Mitchelle',
#   'Mizzi Meyer',
#   'Ryan Gielen',
#   'Shi-Zheng Chen',
#   'Anubhav Sinha',
#   'Kai Kreuser',
#   'Manu Riche',
#   'Dominique Ferrari',
#   'Jacopo Mazzuoli',
#   'Giuseppe Ferrara',
#   'Claudia Llosa',
#   'Samuel A. Taylor',
#   'Leon Griffiths',
#   'Ralph Soll',
#   'Robert Hamilton',
#   'Heidi Maria Faisst',
#   'Valentin Chernykh',
#   'Dan Sallitt',
#   'Jeremy Brock',
#   'Aake Kalliala',
#   'Nevil Shute',
#   'William T. Naud',
#   'Claude Sautet',
#   'Min-hui Seo',
#   'Gregory Marquette',
#   'Constance Beresford-Howe',
#   'Carlos González Dueñas',
#   'Alan Hofmanis',
#   'Benjamin Heisenberg',
#   'Corbin Timbrook',
#   'Manish Shrivastav',
#   'Na. Muthukumar',
#   'Ragnhild Tronvoll',
#   'Deniz Akcay Katiksiz',
#   'Joracy Camargo',
#   'Clément Michel',
#   'André Küttel',
#   'Sirivennela Seetharama Sastry',
#   'Mahmood Farooqui',
#   'Sebastian Street',
#   'Alan Sillitoe',
#   'Philippe Graton',
#   'Nathan Alexander',
#   'Chan-wook Park',
#   'Umberto Saba',
#   'Daniel Woodrell',
#   'Jeremy Adams',
#   'Anthony Calabrese',
#   'Sunil Parameswaran',
#   'János Bródy',
#   'Toshiharu Ikeda',
#   'Dallas Morgan',
#   'David Wike',
#   'Dhani Lipsius',
#   'Christopher Wicking',
#   'Brandy Yuen',
#   'Navin Ramaswaran',
#   'Eduardo M. Clorio',
#   'Harry Narunsky',
#   'Sofia Bohdanowicz',
#   'Eric Goldberg',
#   'Elisabeth Beresford',
#   'Olmo Omerzu',
#   'Tom Tully',
#   'Arthur Morin',
#   'Isaac Cronin',
#   'Shona Urvashi',
#   'Dirk Bracke',
#   'Khalid Boudou',
#   'H.M. Coakley',
#   'Erica Xia-Hou',
#   'Karl Hall',
#   'Pascal Jongen',
#   'Chiang Feng',
#   'Felix Randau',
#   'Maria Sødahl',
#   'Rayya Makarim',
#   'Hsue-chen Hsiao',
#   'William Mickelberry',
#   'Mark Little',
#   'Rachel Tunnard',
#   'James Savoca',
#   'Kit Lai',
#   'Kathleen Slattery-Moschkau',
#   'James Swift',
#   'Reuben Canoy',
#   'Emanuel Schikaneder',
#   'Nahid Tabatabaei',
#   'Vaughn Taylor',
#   'T.P. Rajeevan',
#   'Volker Ludwig',
#   'Valentin Rasputin',
#   'Michael Shoob',
#   'Anoop Sathyan',
#   'William Hoffer',
#   'María Laura Gargarella',
#   'Augusten Burroughs',
#   'Florian Frerichs',
#   'David Pulido',
#   'Anthony Kimmins',
#   'Wain Fimeri',
#   'Deepak Tijori',
#   'Cassandra Peterson',
#   'Naoko Adachi',
#   'J.D. Kendis',
#   'Magdy Ahmed Aly',
#   'Doris Pilkington',
#   'Nikos Nikolaidis',
#   'Minoo Farshchi',
#   'Sonny Laguna',
#   'Julia Britton',
#   'Sooni Taraporevala',
#   'Jay Zaretsky',
#   'Dave Humphries',
#   'Lawrence Riggins',
#   'András Jeles',
#   'William Campbell',
#   'Claude Mulot',
#   'Yun-hee Song',
#   'Karel Kachyna',
#   'David C. Wilson',
#   'Fidel Arizmendi',
#   'Sándor Sára',
#   'Richard Hillary',
#   'Denis Henry Hennelly',
#   'Martín Luis Guzmán',
#   'Frederico Prosperi',
#   'Catherine Binet',
#   'Oleg Antonov',
#   'Neil Fitzmaurice',
#   'Herb Gardner',
#   'Edson Oda',
#   'Reginald Long',
#   'Albertine Sarrazin',
#   'Michael Hofmann',
#   'Patricia Fogliato',
#   'Parasuram',
#   'Santiago Mitre',
#   'James Sweeney',
#   'Deborah Tilton',
#   'Sylvain White',
#   'Mansood Saharanpuri',
#   'François Armanet',
#   'Stefan Avalos',
#   'Molly Prather',
#   'Robert Leaver',
#   'Sergey Chernikov',
#   'Savannah Bloch',
#   'James Graham',
#   'Julian Barry',
#   'Jacob Meszaros',
#   'Benjamin Ross Hayden',
#   'Dean Lorey',
#   'Maeve Binchy',
#   'Henk Handloegten',
#   'Ruggero Rindi',
#   'Charles E. Drew Jr.',
#   'Tom Dever',
#   'Willy Ley',
#   'Kei Hattori',
#   'Michael Logan',
#   'Jordon Hodges',
#   'Claudio Galperin',
#   'Noël Coward',
#   'Jennifer Heaton',
#   'William D. Wittliff',
#   'Daniel Lang',
#   'Manolo Munguia',
#   'Risto Juhani',
#   'Ryûsuke Hamaguchi',
#   'Ian Praiser',
#   'Mehmood Ali',
#   'George Richards',
#   'Nick Szostakiwskyj',
#   'Edward Lee Cornett',
#   'Timothy Griffin',
#   'J. Amanda Sabater',
#   'Stephen Cognetti',
#   'Dan Tondowski',
#   'Mohamed El Sobky',
#   'Amber Lindley',
#   'Lidiya Bobrova',
#   'J. Neil Schulman',
#   'Ana Marija Car',
#   'Heere Heeresma',
#   'Caryl Ferey',
#   'Peter Maple',
#   'Terry Turner',
#   'Yayoisô',
#   "Maura O'Connell",
#   'Clark Cheng',
#   'Giorgio Bonelli',
#   'Tarik Lowe',
#   'Fernando Musa',
#   'Stephen T. Barton',
#   'Jake Hawkins',
#   'Arun Gopinath',
#   'Jacques Viot',
#   'Ray Yeung',
#   'Jeff Stockwell',
#   'John Saunders',
#   'Dana Dimant',
#   'Todd Harthan',
#   'Claudia Liliana García',
#   'Bolton Mallory',
#   'Harvey Pekar',
#   'Derek Chan',
#   'Richard Nockles',
#   'Jo Beom-jin',
#   'C.W. Fallin',
#   'Bob Wehling',
#   'Lotti Pharriss Knowles',
#   'Josh Malerman',
#   'Nicolas Saada',
#   'Jean-Paul Rappeneau',
#   'Ivan Passer',
#   'Héctor Grossi',
#   'Babu Tamizh',
#   'Ruth Jeffries',
#   'Matthew Perniciaro',
#   'Patrick Highsmith',
#   'Dilbag Singh',
#   'Jenni Hall',
#   'James Carrington',
#   'Mike Werb',
#   'John D.F. Black',
#   'Ralph Block',
#   'Juan Carlos Fresnadillo',
#   'Marga Minco',
#   'Emile Asselin',
#   'Víctor Andrés Catena',
#   'Hung-i Chen',
#   'Alex Brendemühl',
#   'Aleksei Fajko',
#   'Subramaniam Siva',
#   'Karim Abbou',
#   'Laird Doyle',
#   'Mara Lesemann',
#   'Gyula Mészáros',
#   'Nicholas Barker',
#   'Lee Eric Smith',
#   'Will Corry',
#   'Christopher Miller',
#   'Groucho Marx',
#   'Dan Benamor',
#   'Fyodor Otsep',
#   'Ruckus Skye',
#   'Eshom Nelms',
#   'Kevin Warner',
#   'Tayarisha Poe',
#   'Amma Asante',
#   'Abdi Nazemian',
#   'Michael Hultquist',
#   'Michael Bacall',
#   'Jayik Sizdikov',
#   'Davíð Oddsson',
#   'Molly Shannon',
#   'Mauricio Chernovetzky',
#   'Fran Araújo',
#   'Alessandro Piva',
#   'Alexander Ziegler',
#   'Gabriel Friedman',
#   'Gil Brailey',
#   'Glória Perez',
#   'Robert Musel',
#   'Erich Ebermayer',
#   'Michael Bortman',
#   'Sun-yeon Hwang',
#   'Peter Mayle',
#   'Don Owen',
#   'Amit Aryan',
#   'Emmanuel Lautréamont',
#   'Mark Leiren-Young',
#   'Julian Kerridge',
#   'Maxime Giroux',
#   'Jules V. Levy',
#   'Sa-hyeon Jang',
#   'Ahu Öztürk',
#   'Kartik R. Iyer',
#   'Norman Lebrecht',
#   'Cecil Chambers',
#   'Esra Saydam',
#   'Josh Ridgway',
#   'Dean Jones',
#   'John G. Thompson',
#   'Vishnuvardhan',
#   'María Eugenia Argomedo',
#   'Bobby Paunescu',
#   'Sebastián Ospina',
#   'Aditya Bhattacharya',
#   'Patrik Syversen',
#   'Manzie Jones',
#   'Jonnie Malachi',
#   'Michelle Morgan',
#   'Yaël Langmann',
#   'Matthew Bright',
#   'Mandy Kaplan',
#   'Lee Eisenberg',
#   'Gary Stuart Kaplan',
#   'Karine Angeli',
#   'Marco Merlo',
#   'Frank Darabont',
#   'Simon Abbott',
#   "Ken'ichi Suzuki",
#   'Jonna Bolin-Cullberg',
#   'Gottfried Kolditz',
#   'Chun Wing Tsang',
#   'Darren Longley',
#   'Norman Lindsay',
#   'Didier Le Pêcheur',
#   'Petri Hakkarainen',
#   'Seth Grahame-Smith',
#   'Jesse Warren',
#   'Sean Robert Daniels',
#   'Edison Marshall',
#   'Tosca Miserendino',
#   'Amman Abbasi',
#   'Fernando Schmidt',
#   'Barry Massoni',
#   'Nitin Chandra',
#   'Hank Orion',
#   'James Klass',
#   'Rupert Hughes',
#   'John O. Hartman',
#   'John M. East',
#   'Paul Slansky',
#   'Daniel Matmor',
#   'Rob Ackerman',
#   'Werner Schroeter',
#   'John Lardner',
#   'Chad Feehan',
#   'Andrew Davis',
#   'Phil Alden Robinson',
#   'Seung-hee Yoo',
#   'Kate Cohen',
#   'Patrick Wang',
#   'David Ryan Keith',
#   'Gaston Biraben',
#   'Chris Shafer',
#   'Brenda Jackson',
#   'Edmund Lee',
#   'Jason Xenopoulos',
#   'Yareli Arizmendi',
#   'Milutin Petrovic',
#   'Gail Segal',
#   'Michael Hartmann',
#   'George Fowler',
#   'Doug Tochioka',
#   'Howard B. Kreitsek',
#   'Nicholas Aikin',
#   'Kamdine Khosrowkhavar',
#   'Nanea Miyata',
#   'Miguel Ibáñez Monroy',
#   'Joe Murtagh',
#   'David Brendel',
#   'Angela Giussani',
#   'Maureen Foley',
#   'Shonali Bose',
#   'Bjørn Sand',
#   'Eric Holder',
#   'Erik Saltzgaber',
#   'Ayça Damgaci',
#   'David Svec',
#   'Bruce Le Writers Group',
#   'Neal H. Dobrofsky',
#   'Ana Zins',
#   'Andrew Jay Cohen',
#   'Emmanuelle Arsan',
#   'Jan Egleson',
#   'Alan Sacks',
#   'Ayse Sasa',
#   'William D. Bostjancic',
#   'Laure Hennequart',
#   'Jay Sommers',
#   'Edgar Rice Burroughs',
#   'Fahmi Fadzil',
#   'David Worth',
#   'Vamsi Rajesh Kondaveeti',
#   'Grant Scicluna',
#   'Arun Bhairav',
#   'David Fuller',
#   'Jim Vines',
#   'Kaspar Rostrup',
#   'Max Heller',
#   'John Romo',
#   'Jordan Goldnadel',
#   'Eleanor Brooke',
#   'Dred Ross',
#   'Andrzej Golda',
#   'Herbert Brenon',
#   'J.G. Hawks',
#   'R. Herbert',
#   'Dieter Dicken',
#   'Paul Frizler',
#   'Tino Insana',
#   'Glenio Bonder',
#   'Dorothy Fields',
#   'Anthony Wisdom',
#   'James Clavell',
#   'Bruce Campbell',
#   "Frank D'Angelo",
#   'Chandoo Mondeti',
#   'Anthony Minghella',
#   'John Kneubuhl',
#   'Patrick Foulk',
#   'Sheilah Graham',
#   'László Vadnay',
#   'Maria von der Osten-Sacken',
#   'Scott Elliott',
#   'Atsushi Yamatoya',
#   'Taeko Tomioka',
#   'Harry Sauber',
#   'Benoît Graffin',
#   'Darnell J. Taylor',
#   'Kroll Azry',
#   'Fernando Trueba',
#   'Mustafa Neemuchwala',
#   'Bryan Erwin',
#   'Bulle Ogier',
#   'Dale Neven',
#   'Tossaphon Riantong',
#   'Édouard Molinaro',
#   'Pierre Duculot',
#   'Shunyo Yanagawa',
#   'J.G. Ballard',
#   'John Francis Larkin',
#   'Dennis Cooley',
#   'Stuart Brennan',
#   'Zach Shields',
#   'Yitzhak Ginsberg',
#   'John Newcombe',
#   'Eun-ha Jo',
#   'Peter Callow',
#   'Rita Douglas',
#   'Terence Nance',
#   'Randy Moore',
#   'Scott Firestone',
#   'Manijeh Hekmat',
#   'Jeff Wild',
#   'Scott Edmund Lane',
#   'Charles Matthau',
#   'Lee Hall',
#   'Peter Gamble',
#   'Jacky St. James',
#   'Catherine Breillat',
#   'Stephen Sheppard',
#   'Satyen Bose',
#   'Wayne Behar',
#   'Danny Acosta',
#   'Christian Clavier',
#   'David M. Kaufman',
#   'Richard Dillon',
#   'Tamer Hosny',
#   'Roberto Rossellini',
#   'Earle Lyon',
#   'Richard N. Goodwin',
#   'Aryan Kaganof',
#   'Federico Alotto',
#   'Larry K. Johnson',
#   'Kavita Choudhary',
#   'Duncan MacNeillie',
#   'Bruce Benderson',
#   'Phillip Gwynne',
#   'Rafael Sánchez Campoy',
#   'Roope Olenius',
#   'Erland Josephson',
#   'Zizak',
#   'Ladislav Grosman',
#   'Klearhos Konitsiotis',
#   'Michel Sabbe',
#   'Jason Todd Ipson',
#   'Sergey Bondarenko',
#   'Adam Cushman',
#   'Ji-hye Kim',
#   'Yipeng Ben Lu',
#   'Steve Klein',
#   'Lotta Thell',
#   'Julián Ibáñez',
#   'Seok-Geun Lee',
#   'Daniel Monedero',
#   'Michaël R. Roskam',
#   'Therese Conte',
#   'Robert Chimento',
#   'Lingard Jervey',
#   'Bobby Khan',
#   'Park Jung-Hee',
#   'Louis-Pascal Couvelaire',
#   'Eirik Moe',
#   'Casey Affleck',
#   'J.P. Dutta',
#   'Art Clokey',
#   'Jérôme Géronimi',
#   'David Rountree',
#   'Tikiri Hulugalle',
#   'Dave Parker',
#   'Martin Hollý',
#   'Doug Bagot',
#   'Robert Carlock',
#   'Xiaowei Tian',
#   'Eddie Moran',
#   'Joseph Than',
#   'Jack Higgins',
#   'Hurford Janes',
#   'Troy Escamilla',
#   'Vipin Bhati',
#   'Martin Leidenfrost',
#   'Sharri Hefner',
#   'Jen Tullock',
#   'Andrzej Strug',
#   'W. Maxwell Goodhue',
#   'Ryu Yong-jae',
#   'William Lively',
#   'Marlen Haushofer',
#   'S.L. Puram Jayasurya',
#   'Pierre Schoendoerffer',
#   'Wesley Chan',
#   'Grant Garett',
#   'Paul Quinn',
#   'Adrian Edmondson',
#   'Leo Kunnas',
#   'Philipp Weinges',
#   'Kazuo Daijo',
#   'Buster Keaton',
#   'Julian Unthank',
#   'Juan Avilez',
#   'Xawery Zulawski',
#   'Rajen Makhijani',
#   'Edna Ferber',
#   'Walter Gorrish',
#   'Jorge Pérez Solano',
#   'Aaron Harvey',
#   'Masahiro Ito',
#   'Jerusha Hess',
#   'Carmen Ballesteros',
#   'Maggie April',
#   'Jeremy Berg',
#   'Tabajara Ruas',
#   'Manuel Komroff',
#   'Julie Richard',
#   'Debora Heflin',
#   'Pierre Portelli',
#   'Yen-Ping Chu',
#   'Daisuke Tengan',
#   'Fred Gallo',
#   'Anna De Pagter',
#   'Ben Collins',
#   'Marina Mareeva',
#   'Lauri Törhönen',
#   'Olli Soinio',
#   'Nar Sene',
#   'Marcelo Saback',
#   'Maurice Barthélémy',
#   'Ali F. Mostafa',
#   'Martine Dugowson',
#   'Ian Maclaren',
#   'Jeffrey M. Smith',
#   'Oliver Parker',
#   'T.R. McCauley',
#   'Selami Genli',
#   'Percival Rubens',
#   'Scot Finch',
#   'James Wan',
#   'Lance Lee Davis',
#   'Deepu S. Nair',
#   'Oscar Hammerstein II',
#   'Christina Welsh',
#   'Eddie Alcazar',
#   'Rebecca Swan',
#   'Mauricio Valle',
#   'Martin Lawrence',
#   'Virginia Hamilton',
#   'Gil Courtemanche',
#   'Anna Klamburg',
#   'Jazmín Stuart',
#   'Daniel Zelman',
#   'Runer Jonsson',
#   'Claudia Florio',
#   'Cécile Sellam',
#   'Bhavani Iyer',
#   'Zack Ward',
#   'John Reign',
#   'Yutaka Izubuchi',
#   'Claudius Pläging',
#   'Clive Brook',
#   'Thomas B. Costain',
#   'Thomas Maurer',
#   'Nico Mastorakis',
#   'Art Arthur',
#   'Victor Saville',
#   'Ahmed Fahmy',
#   'Reed De Rouen',
#   'Cyril Collard',
#   'Russ Tamblyn',
#   'Filiberto Bandini',
#   'Masashi Sada',
#   'TJ Nordaker',
#   'Bill Richmond',
#   'Wen-Hua Cheng',
#   'Siu Cheung Chan',
#   'Rebecca Miller',
#   'Shailendra Tiwari',
#   "Vincent O'Connell",
#   'Alfonso Cuarón',
#   'Alexo Petrov',
#   'Shana Feste',
#   'Owais Korai Baloch',
#   'Ken Metcalfe',
#   'Greg DeLiso',
#   'Cherie Bennett',
#   'André van Heerden',
#   'A.S.M. Hutchinson',
#   'K.K. Raina',
#   'David J. Douglas',
#   'Harold Brodkey',
#   'Matthew Toronto',
#   'Grete Salomonsen',
#   'Jerzy Skolimowski',
#   'Mordaunt Shairp',
#   'Josef von Sternberg',
#   'Francesco Valitutti',
#   'Sandra Vo-Anh',
#   'Takashi Nishiyama',
#   'Werner Herzog',
#   'Jon Jost',
#   'Walter Ferris',
#   'Juraj Lehotsky',
#   'Zvonimir Juric',
#   'Tôma Kitabayashi',
#   'John Brason',
#   'Kathryn F. Taylor',
#   'Neill Dela Llana',
#   'Bradley King',
#   'Lev L. Spiro',
#   'Scott Bates',
#   'Dylan Kidd',
#   'Georges Darrier',
#   'Tony Owen',
#   'Dan Palmer',
#   'Lauren Himmelvo',
#   'Philipp Roth',
#   'Ian Paxton',
#   'Jacques Poitrenaud',
#   'Wim Verstappen',
#   'Simone Lenzi',
#   'Austin Strong',
#   'Reginald Owen',
#   'Jeong Heo',
#   'Jack Moffitt',
#   'Domenico Blass',
#   'Kyle Ham',
#   'Sam Lipsyte',
#   'Jeremy Lee Francis',
#   'Chris Henchy',
#   'Blanche Hanalis',
#   'Tim Pope',
#   'Stole Popov',
#   'Michael J. Epstein',
#   'Darren Bolton',
#   'Dan Duling',
#   'Christel Gräf',
#   'Lik-Chi Lee',
#   'Ricou Browning',
#   'Harry Preston',
#   'Tom Rowe',
#   'Luis César Amadori',
#   'Frank Hart Taussig',
#   'Danny McBride',
#   'Frank Bovenkerk',
#   'Eamon Hardiman',
#   'William R. Johnson',
#   'Tony Klinger',
#   'Daniel Raskov',
#   'James Dalessandro',
#   'Matthew Chapman',
#   'Richard Conlin',
#   'Junli Tian',
#   'Robert Chomiak',
#   'John W. Richardson',
#   'Juan Bonilla',
#   'Louis Gardel',
#   'Jason Daly',
#   'Micah Caronna',
#   'Lawrence Robinson',
#   'Maureen Mylander',
#   'Don Simmons',
#   'Albert Richard Wetjen',
#   'Catherine Johnson',
#   'Toby Keith',
#   'Hamé Bourokba',
#   'Hiroshi Fukazawa',
#   'Vesa-Matti Loiri',
#   'Darlene Craviotto',
#   'Fumio Moriya',
#   'Hatem Khraiche',
#   'Sean S. Cunningham',
#   'Christopher Sturgeon',
#   'Michael Nicholson',
#   'Franck Vestiel',
#   'Xander Wolf',
#   'Jamshid Mahmoudi',
#   'Sara Flanigan',
#   'Michael Grant Jaffe',
#   'Leofwine Loraine',
#   'Simon Moutairou',
#   'Bruce Joel Rubin',
#   'Allan Dale Kuhn',
#   'Woo-sang Park',
#   'Anna Boden',
#   'Nick Carter',
#   'Nicole Armbruster',
#   'Jack Andrews',
#   'Kyle Bogart',
#   'Kenneth Stevenson',
#   'Todd Sklar',
#   'Peter Bognanni',
#   'Pieter Van Hees',
#   'Justin D.M. Palmer',
#   'Gatarô Man',
#   'Scott Tepperman',
#   'Cody Berry',
#   'Alan Hackney',
#   'Jane Hawksley',
#   'John Hamill',
#   'Nick Mead',
#   'Nicholas Phipps',
#   'Maciej Pieprzyca',
#   'Nonzee Nimibutr',
#   'Scott Vickers',
#   'Claude Goretta',
#   'Peter Curran',
#   'Alan Paz',
#   'Elfriede Jelinek',
#   'Patrick Desmond',
#   'Margreth Olin',
#   'Pierce Ryan',
#   'Gisaburô Sugii',
#   'Mark Venner',
#   'Susumu Saji',
#   'W.O. Mitchell',
#   'John R. Gordon',
#   'Stefan Fjeldmark',
#   'Dennis Aaberg',
#   'Shaun Angus Hall',
#   'Santiago Parra',
#   'Scott Davis Jones',
#   'Aakash Kaushik',
#   'Jonathan Stark',
#   'Michael Standing',
#   'Yasutarô Yagi',
#   'Aiden Dillard',
#   'John Carlos Frey',
#   'Manuel Gómez Pereira',
#   'Kamoshida Hajime',
#   'Futoshi Nakano',
#   'Carl Theodor Dreyer',
#   'Chris Andrews',
#   'Allen Wolf',
#   'Gabriel Retes',
#   'Sheri Elwood',
#   'Alan Aylward',
#   'Bob Odenkirk',
#   'Felix Lützkendorf',
#   'John Riley',
#   'Angeli',
#   'Lucas Heyne',
#   'Raymond Griffith',
#   'Josh Austin',
#   'Dominique Faysse',
#   'Sarah Besan Shennib',
#   'Brian Herzlinger',
#   'Peter von Mendelssohn',
#   'Hinako Nakazawa',
#   'Babak Najafi',
#   'Suhas',
#   'Szeto Kam',
#   'Hong-Seung Yoon',
#   'Enzo G. Castellari',
#   'Becca Topol',
#   'Thomas Stavros',
#   'Neil Jaworski',
#   'Olavi Karu',
#   'Don Coscarelli',
#   'Shinzô Fujita',
#   'Ron Hutchinson',
#   'Mihiro',
#   'Anthony Hickox',
#   'Scott Owen',
#   'Ormonde Dekay Jr.',
#   'Nelson Rodrigues',
#   'André Schneider',
#   'Allen McNeil',
#   'Aleksey Kozlov',
#   'Jan Otcenásek',
#   'Vincenzo Labella',
#   'David Carren',
#   'Ryan Lee Driscoll',
#   'Robert Bolesto',
#   'Shoojit Sircar',
#   'Rajesh. K.',
#   'Gillian Freeman',
#   'Carl Rees',
#   'Joaquín Luis Romero Marchent',
#   'Obrad Gluscevic',
#   'Philip Roth',
#   'Polo Menárguez',
#   'Francesco Cinquemani',
#   'Kenyon J. Scudder',
#   'Louis-Paul Desanges',
#   'David Z. Weinstein',
#   'Senel Paz',
#   'Dwight Istanbulian',
#   'Neal Marshall Stevens',
#   'Vlas Parlapanides',
#   'Noah Oppenheim',
#   'Julian Dahl',
#   'Michael Berk',
#   'Henrik Ruben Genz',
#   'Joe DiPietro',
#   'Stuart Browne',
#   'Amy Callaway',
#   'Patricio Lynch',
#   'Michael Clancy',
#   'Erich Kästner',
#   'Ray Mayer',
#   'Michel Munz',
#   'Lao Ni',
#   'Óskar Jónasson',
#   'Preston A. Whitmore II',
#   'Steve Gerber',
#   'Goodman Ace',
#   'Alexander Titus Benda',
#   'Daphna Edwards',
#   'Ed Earl Repp',
#   'Chui Mui Tan',
#   'Alberto Fioretti',
#   'Betse De Paula',
#   'Prof. Mathesius',
#   'Mitch Gould',
#   'Michael Boughen',
#   'Gina Riley',
#   'Dmitriy Zhigalov',
#   'Richard Clement Haber',
#   'Sudeep',
#   'Joseph Quillan',
#   'D.A. Loxley',
#   'Roman Zaluski',
#   'Peter Ormrod',
#   'Maria Maggenti',
#   'C.J. Santiago',
#   'Andrew Scheinman',
#   'Adrienne Stout',
#   'Dale Eunson',
#   'Chris Jaymes',
#   'David McIntosh',
#   'James Bridie',
#   'Manoj Lalwani',
#   'Anna Iztaru',
#   'Kim Chapiron',
#   'Colin Carberry',
#   'William Ford Manley',
#   'Richard Ryan',
#   'Franck Moisnard',
#   'Bryan Schulz',
#   'Ashley Cahill',
#   'Kenneth Davenport',
#   'Charles Purpura',
#   'James Cardoza',
#   'Stanley Shapiro',
#   'Benito Zambrano',
#   'Bonz Malone',
#   'Marc Fitoussi',
#   'Robert T. Westbrook',
#   'Jimmy Loweree',
#   'Shaktimaan Talwar',
#   'Kerstin Gezelius',
#   'Martin Forget',
#   'Rosa Dias',
#   'Ben Feiner Jr.',
#   'Kurt Kuenne',
#   'Bussunda',
#   'Matt Shumway',
#   'Rob W. King',
#   'Richard Franklin',
#   'Adam Ripp',
#   'Scott Donnelly',
#   'Terry Chase Chenowith',
#   'Dorothy Wall',
#   'Herman C. McNeile',
#   'Anne Mather',
#   'Rick Alvarez',
#   'Salil Choudhury',
#   'Marlon Olivierre',
#   'Roy Hamilton',
#   'Mac Ahlberg',
#   'Paul Butler',
#   'Philip Kaufman',
#   'Danny Finnerty',
#   'Michael Ciminera',
#   'Jostein Gaarder',
#   'Horst Freund',
#   'James Hughes',
#   'Maurice Sandoz',
#   'Valdís Óskarsdóttir',
#   'Didier Cohen',
#   'Selma Lagerlöf',
#   'Ondrej Stindl',
#   'Christopher Joyce',
#   'Sophie Laloy',
#   'Hilda Hársing',
#   'Fernando Bonassi',
#   'Philippe Blot',
#   'Nic Balthazar',
#   'John Esposito',
#   'Carol Doyle',
#   'Keith Coulouris',
#   'Edward Boyd',
#   'Mahmood Arbabi',
#   'Jeevan Job Thomas',
#   'Isabel Colegate',
#   'David Amito',
#   'David Howard',
#   'Ho-Leung Lau',
#   'Richard Shepard',
#   'Jan-Willem den Bok',
#   'Debaloy Bhattacharya',
#   'Jon Sorensen',
#   'Kaoru Takamura',
#   'Tyler Christensen',
#   'Evgeniy Pashkevich',
#   'Victor Alexandrov',
#   'Harry Ruby',
#   'Philip Creager',
#   'Mark Cheng',
#   'Jacques Davidts',
#   'R.F. Delderfield',
#   'Nino Battiferri',
#   'Daniel Boyd',
#   'David Mingay',
#   'George Baxt',
#   'James Nichols',
#   'David Teitelbaum',
#   'In-mu Heo',
#   'Iafa Britz',
#   'Barbara Vekaric',
#   ...},
#  54287)

# %% [markdown]
# ## Insight into Movie Production companies from top movie production company

# %%
IMDBdata.production_company.nunique()
# Out:
# 29121

# %%
IMDBdata.production_company.value_counts()
# Out:
# Metro-Goldwyn-Mayer (MGM)              1267
# Warner Bros.                           1143
# Columbia Pictures                       909
# Paramount Pictures                      888
# Twentieth Century Fox                   863
#                                        ...
# SP Inc.                                   1
# Moving Target Film Productions Ltd.       1
# The French Connection                     1
# Noise & Light                             1
# TBOK Production                           1
# Name: production_company, Length: 29121, dtype: int64

# %% [markdown]
# ### **USA's top movie production companies**

# %%
IMDBdata[IMDBdata.country =='USA']['production_company'].nunique()
# Out:
# 11076

# %%
IMDBdata[IMDBdata.country =='USA']['production_company'].value_counts().head(20)
# Out:
# Metro-Goldwyn-Mayer (MGM)                1182
# Warner Bros.                              967
# Paramount Pictures                        771
# Twentieth Century Fox                     760
# Columbia Pictures                         738
# Universal Pictures                        563
# RKO Radio Pictures                        530
# Universal International Pictures (UI)     272
# Republic Pictures (I)                     208
# First National Pictures                   152
# New Line Cinema                           150
# Touchstone Pictures                       114
# Monogram Pictures                         114
# Walt Disney Productions                   110
# Fox Film Corporation                      104
# Walt Disney Pictures                       91
# Sam Katzman Productions                    82
# TriStar Pictures                           79
# Allied Artists Pictures                    69
# The Samuel Goldwyn Company                 66
# Name: production_company, dtype: int64

# %% [markdown]
# ### **India's top movie production companies**

# %%
IMDBdata[IMDBdata.country =='India']['production_company'].nunique()
# Out:
# 2205

# %%
IMDBdata[IMDBdata.country =='India']['production_company'].value_counts().head(20)
# Out:
# NH Studioz                                               107
# SVF Entertainment                                         54
# Yash Raj Films                                            48
# Eros International                                        38
# Dharma Productions                                        35
# Sri Venkateswara Creations                                25
# Fox STAR Studios                                          24
# UTV Motion Pictures                                       23
# Angel Digital Private Limited                             19
# National Film Development Corporation of India (NFDC)     19
# Mukta Arts                                                19
# Raajkamal Films International                             18
# Rajshri Productions                                       17
# Everest Entertainment                                     17
# Balaji Motion Pictures                                    16
# R.K. Films Ltd.                                           16
# Geetha Arts                                               15
# Annapurna Studios                                         15
# Percept Picture Company                                   15
# Aashirvad Cinemas                                         15
# Name: production_company, dtype: int64

# %% [markdown]
# ### **UK's top movie production companies**

# %%
IMDBdata[IMDBdata.country =='UK']['production_company'].nunique()
# Out:
# 1910

# %%
IMDBdata[IMDBdata.country =='UK']['production_company'].value_counts().head(20)
# Out:
# The Rank Organisation                            107
# Hammer Films                                      68
# Gainsborough Pictures                             67
# Ealing Studios                                    63
# London Film Productions                           59
# Associated British Picture Corporation (ABPC)     58
# BBC Films                                         48
# Two Cities Films                                  38
# Gaumont British Picture Corporation               36
# Columbia Pictures                                 34
# Channel Four Films                                31
# British Broadcasting Corporation (BBC)            29
# British Screen Productions                        25
# Romulus Films                                     24
# Columbia Pictures Corporation                     23
# J. Arthur Rank Organisation                       22
# EMI Films                                         22
# Peter Rogers Productions                          20
# British Film Institute (BFI)                      19
# Arts Council of England                           19
# Name: production_company, dtype: int64

# %% [markdown]
# # Insight into actors

# %%
IMDBdata.columns
# Out:
# Index(['imdb_title_id', 'original_title', 'year', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'reviews_from_users'],
#       dtype='object')

# %%
list_unique_values_in_column(IMDBdata, 'actors')
# Out:
# ({'John Franklyn-Robbins',
#   'Sung-min Lee',
#   'Jason R. Davis',
#   'Jimmy Broome',
#   'Gyula Nagy',
#   'Bob Gerry',
#   'Danyi Li',
#   'Rosie Benton',
#   'Daniel Howard',
#   'Fany Sakantany',
#   'Yana Sekste',
#   'Khairi Burieva',
#   'Cassie Williams',
#   'Hanna Schmidt-Foß',
#   'Terri Garber',
#   'Gloria DeHaven',
#   'Sig Kantor',
#   'Kevin Flatley',
#   'Micah Pryor',
#   'Myles Robertson',
#   'Audrey De León',
#   'Neha Reddy',
#   'Sara Sálamo',
#   'Sara Dinic',
#   'Jean Glaudé',
#   'Peter Dubiel',
#   'Memduh Ünsal',
#   'Laura Govan',
#   'Migdalia Melendez',
#   'Lola Pagnani',
#   'Diana Chappell',
#   'Paolo Vivaldi',
#   'Shirô Ôsaka',
#   'Mick Hodge',
#   'Susana Moody',
#   'Helen Lesnick',
#   'Douglas Bisset',
#   'Alma Sinai',
#   'Bill Berry',
#   'João Santos Lopes',
#   'Renate Feuereisen',
#   'Mathias Minne',
#   'Bruce Myles',
#   'Anne Winton',
#   'Felipe de Flores',
#   'Stephanie Kronenberg',
#   'Ana Cimini',
#   'Cyd Charisse',
#   'Livia Brito',
#   'Anna Jennette',
#   'Viola Keats',
#   'Louise Frevert',
#   'Robert Hegyes',
#   'Abdulla Sunado',
#   'Sarah Constance Smith Hunt',
#   'Ava Tyler',
#   'Richard Swift',
#   'The Vagabonds',
#   'Paul Bradley',
#   'Gary Kasper',
#   'Aladeen Tawfeek',
#   'Orkun Karagöz',
#   'Omar Fakhr',
#   'James Awuy',
#   'Claude Aufaure',
#   'Gillian Gordon',
#   'Justin Barr',
#   'Elisabetta Virgili',
#   'Ankur Nayyar',
#   'Michael Sugich',
#   'Stéphane Darmon',
#   'Wart Kamps',
#   'Sonalii Castillo',
#   'Torunn Lødemel',
#   'Aake Kalliala',
#   'Nayanthara',
#   'Junior John Levis',
#   'German Kolushkin',
#   'Nina Ivanovich',
#   'Sonja Lambersek',
#   'Walter Beaver',
#   'Hugh Ettinger',
#   'Clément Michel',
#   'Ismaïla Meite',
#   'Shoshana Sperling',
#   'Miguel Seabra',
#   'Alan Tomaev',
#   'Danny Higham',
#   'Willard E. Pugh',
#   'Siohbon Chevy Ebrahimi',
#   'Kô Hirota',
#   'Shilpa Bala',
#   'Artemia Terenziani',
#   'Ali',
#   'Clemency Burton-Hill',
#   'Ryan LeBoeuf',
#   'Nathanael Cooper',
#   'Brian Lally',
#   'Nigel Harrison',
#   'Ali Sami Akdeniz',
#   'Danilo Nigrelli',
#   'Camille Farnan',
#   'Kaori Takasugi',
#   'Harry Braxton Davis',
#   'Shôgo Yamaguchi',
#   'Kôji Nanbara',
#   'Edie Mirman',
#   'Scott Weinger',
#   'Kuniko Tomita',
#   'Gen Kuroki',
#   'Humberto Miranda',
#   'Afzal Hossain',
#   'Dana Rogoz',
#   'Iván Montes',
#   'Viletta Skillman',
#   'Emilio Massera',
#   'Renee Cariven',
#   'Gulshan Pandey',
#   'Jon Lavranos',
#   'Catherine Jacob',
#   'Susanne Meneghel',
#   'Ali Benaceur',
#   'Courtney Luskie',
#   'Karthika Muraleedharan',
#   'Mark Little',
#   'Kate Sannella',
#   'Steven Radusinovic',
#   'Cliff Ketchum',
#   'Muharrem Gürses',
#   'Jean Colleran',
#   'Carlo Maceda',
#   'Deniz Gürzumar',
#   'John C. Reilly',
#   'Seung-hwan Baek',
#   'Jean Pâqui',
#   'Dean Yacalis',
#   'George Ferrier',
#   'Colleen Carey',
#   'Viktor Dobrovolsky',
#   'Manu Jose',
#   'Sofia Leite',
#   'Marc Dantes',
#   'Shad Carroll',
#   'William Greaves',
#   'Aurel Cioranu',
#   'Cassandra Peterson',
#   'Patricia Landon',
#   'Justine Warrington',
#   'Bob Holt',
#   'Tasha Taaqpak Panigeo',
#   'Benny Pradhan',
#   'Thurl Ravenscroft',
#   'Ramón Durán',
#   'Zelda R. Suplee',
#   'Yulia Hancheroff',
#   'Jonathan Dodge',
#   'María Rosenfeldt',
#   'Lisa Altomare',
#   'Loli Cafetzoglus',
#   'E. Bernhard Warg',
#   'Hywel Bennett',
#   'Andrei Runtso',
#   'Alexia Hall',
#   'Mohan Agashe',
#   'Kofi Agyemang',
#   'Louis de Menthon',
#   'Ah-Niu',
#   'João Acaiabe',
#   'David Koechner',
#   'Sam Ford',
#   'Anja Jochimsen',
#   'Ted Maynard',
#   'Harumi Sone',
#   'Jan Drawnel',
#   'Zach Gray',
#   'Tyler Hanes',
#   'Ralph Morino',
#   'Yalçin Akçay',
#   'Azmyth Kaminski',
#   'Karanvir Sharma',
#   'Kory Grim',
#   'Bill Pickels',
#   'Eileen Alana',
#   'Kate Bayley',
#   'Deborah Tilton',
#   'Céleste Carrale',
#   'Flemming Jørgensen',
#   'Stefan Avalos',
#   'Alejandro Parodi',
#   'Randy Thomas',
#   'Geoffrey Rivas',
#   'Daniel Negreanu',
#   'Luke Doloi',
#   'Graham Leaman',
#   'Aral Gribble',
#   'Yut-bing Wong',
#   'Johnna Johnson',
#   'Amy Waller',
#   'Robin Douglas',
#   'Dan Chandler',
#   'Eric Beekes',
#   'Desmond Bull',
#   'Jennifer Barnes',
#   'Nicole Murgia',
#   'Fernando García Toriello',
#   'Dora Bekesi',
#   'Ann-Marie Jolly',
#   'Rasheed',
#   'Graham Saxon',
#   'Rickie Sorensen',
#   'Helena Norowicz',
#   'Daniela De Silva',
#   'Earl White',
#   'Temuri Qamkhadze',
#   'Richard Comar',
#   'Arifin Putra',
#   'Lucía Cortez',
#   'Ioana Abur',
#   'Aldo Fiorelli',
#   'Nathan Harrington',
#   'Lillemor Hungi',
#   'Chao Wu',
#   'Henry Capps',
#   'Kpy Sathish',
#   'Christopher Jennings',
#   'Laurence Whitley',
#   'Tiehong He',
#   'Mario Auritano',
#   'Eugène Lourié',
#   'Manwendra Tripathy',
#   'Eric Ray Anderson',
#   'Bingo Mbonjeni',
#   'Vito Galetta',
#   'Kenneth Harlan',
#   'Milena Predic',
#   'Charblay',
#   'Rousso',
#   'Luke Ward-Wilkinson',
#   'Laura Chiu',
#   'Lorenzo Balducci',
#   'Jeong-eun Lim',
#   'Elizabeth Robertson',
#   'Jeannie Andresakes',
#   'Diego Calderón',
#   'Ivy George',
#   'Dee Dee Barksdale',
#   'Harrison Zanuck',
#   'Matthew Perniciaro',
#   'Zbigniew Dziduch',
#   'Nikki Kat',
#   'Christopher Gutierrez',
#   'Leonardo Guzmán',
#   'Mario Fabrizi',
#   'Juliet Reichert',
#   'Robert Fattori',
#   'Sarah H. Wilkinson',
#   'Tom Stedham',
#   'Laine Neil',
#   'Bernard Noël',
#   'Kalle Palzer',
#   'Aram Stephan',
#   'Josh Fried',
#   'Tanya Linette Smith',
#   'Ayaka Horie',
#   'Subhra Sourav Das',
#   'MacCallister Byrd',
#   'Sasha Roy Bellina',
#   'Yueyun Liang',
#   'Danae Torn',
#   'Kaveh Najmabadi',
#   'Sergio Limon',
#   'Emin Esen',
#   'Bryson Jones Allman',
#   'Elvira Isasi Loma Ossorio',
#   'Tony Almont',
#   'Ian Kim',
#   'Hollis McCarthy',
#   'Mehmet Esen',
#   'Emilian Marnea',
#   'Maray Ayres',
#   'Sean Kenin',
#   'Steve Hart',
#   'Diletta Acquaviva',
#   'Kentarô Tamura',
#   'Hans-Joachim Möbis',
#   'Go-Eun Ryu',
#   'Romuald Weber',
#   'Laurie Snyder',
#   'Bruce Finlay',
#   'Kwong Wan',
#   'Philippe Pierrard',
#   'Annieye Cárdenas',
#   'Bradford Fairbanks',
#   'Ralph Bruneau',
#   'Wen Shen',
#   'Ziza Stojanovic',
#   'Ben Giacometti',
#   'Yin Chang',
#   'Rachid Salloum',
#   'Ramesh Kottayam',
#   'Marie Lund Asholt',
#   'Bekim Guri',
#   'Josh Ridgway',
#   'Mark W. Johnson',
#   'Robert Kurcz',
#   'Vishnuvardhan',
#   'Natalya Shchesnyak',
#   'Patrick Baca',
#   'Sonia Aguilar',
#   'Ruth Durley',
#   'Vera Blagovidova',
#   'Kristine Nicolopoulos',
#   'Dion Mucciacito',
#   'Raleigh Gardenhire',
#   'Véronique Volta',
#   'George Grigore',
#   'Michal Gazda',
#   'Joshua Dela Cruz',
#   'Min Tian',
#   'Steele Justiss',
#   'Lynn-Marie Stetson',
#   'Rolf Tasna',
#   'Megan Wilson',
#   'Guillaume Champoux',
#   'Dave Stout',
#   'Nick Cimiluca',
#   'Gustaf Elger',
#   'Hajime Asô',
#   'Gloria Sirabella',
#   'Zoë Gameau',
#   'Brad Koed',
#   'Vincent Dénériaz',
#   'Francesco Acquaroli',
#   'Sam Crutsinger',
#   'Hondo',
#   'Rufus Hound',
#   'Colleen Kelly',
#   'Clebert Ford',
#   'Lauren Leigh Phillips',
#   'Henrietta Williams',
#   'Zhifen Gu',
#   'Werner Gerlach',
#   'Julie Guevara',
#   'Philip Spensley',
#   'Anthony Singh',
#   'Man-Yin Ho',
#   'Fodia Coulibaly',
#   'Ricardo Gross',
#   'Raghav Tiwari',
#   'Eric Peter',
#   'Wilmien Rossouw',
#   'Popetorn Soonthornyanakij',
#   'Edo Van Breemen',
#   'Elza Lezhdey',
#   'John Funk',
#   'Roxanne Brewer',
#   'Vince Cupone',
#   'Catherine Ellison',
#   'Esther Issaka',
#   'Kristin Avery',
#   'Jone Hope Larsen',
#   'Amith Lokesh',
#   'Kathryn Playa',
#   'Akira Takatsuki',
#   'Olga Velbria',
#   'Stéphanie Aubry',
#   'Dato de Oliveira',
#   'Peter Lanigan',
#   'Abraham Lim',
#   'David Worth',
#   'Alex McNally',
#   'Daniel Wilkinson',
#   'Pamela Stirling',
#   'Bercuhi Berberyan',
#   'Victoria Meade',
#   'Jody Kay',
#   'Amine Mejri',
#   'Maritza Santiago Hernandez',
#   'Maxwell Reed',
#   'Laura Anne Barkett',
#   'Mariona Castillo',
#   'Myrrh Cauthen',
#   'Olga Peytavi-Müller',
#   'Ron Edwars',
#   'Rudi Simmons',
#   'Tanvi Hegde',
#   'Lorria Richards',
#   'Lou Lewis',
#   'Harald Abdelhamed',
#   'Alicia Moro',
#   'Mr. Chin',
#   'Shehzad Askari',
#   'Carter Friend',
#   'Matty Ryan',
#   'Vasile Filipescu',
#   'Tre Cool',
#   'Michiko Hoshi',
#   'Nadia Farès',
#   'Gus Arnheim and His Orchestra',
#   'Tim X. Lee',
#   'Brian Takats',
#   'Clinton Austin Shirley',
#   'Lindy Whiteford',
#   'Darko Savor',
#   'Monoxide',
#   'Alka Chatwal',
#   'Suzanne von Borsody',
#   'Ellie Chidzey',
#   'Takumi Saitoh',
#   'Rush Williams',
#   'Matthew Scott Wilcox',
#   'Terence Nance',
#   'Gian Maria Volontè',
#   'Sainty Nelsen',
#   'John Ventantonio',
#   'Ayla Kell',
#   'Bodhi Elfman',
#   'Clémence Blondeau',
#   'Reece Noi',
#   'Buster Wilson',
#   'Louise English',
#   'Christoph Letkowski',
#   'Pierre Cartonnet',
#   'Maria Fekete',
#   'Bobby Max',
#   'Fabrizio Brandi',
#   'Danny Acosta',
#   'Alicélia Batista Cabreira',
#   'Kenneth Belton',
#   'Alison Brougham',
#   'Stephan Smith Collins',
#   'Erika Tweer',
#   'Natalya Vorobyova',
#   'Edwin Thomas',
#   'Brian Mallon',
#   'Sylvio Archambault',
#   'Ivo Rogulja',
#   'Agostino Scuderi',
#   'Luis Beristáin',
#   'Thanos Mitropoulos',
#   'Patty McDonald',
#   'Dawan Scott',
#   'Christiane Joguet-Laborde',
#   'Gray Lawson',
#   'Gaelyn Mendonca',
#   'M.S. Thrippunithara',
#   'Ashok Asrani',
#   'Akio Suyama',
#   'Malena Majul Lieun',
#   'Valya Belykh',
#   'Roxane Dubart',
#   'Sarah Gaugler',
#   'Julian Garner',
#   'Ruth Lin',
#   'Roger Breland',
#   'Marissa Tait',
#   'Ray Barnes',
#   'Lorna Lewis',
#   'Jyothi Rana',
#   'Indrans',
#   'Ta-Nan Huang',
#   'John Pingayak',
#   'Nigel Harris',
#   'Darrio Stangl',
#   'Martin Hollý',
#   'Naomi Hewer',
#   'Christian Saldert',
#   'Arslane Lerari',
#   'Brandon Thane Wilson',
#   'Vladimir Tesovic',
#   'Yuki Kimura',
#   'Jeddah Danielle Salera',
#   'Ben Braun',
#   'Fernando Halman',
#   'Petre Fumuru',
#   'Barb Brebner',
#   'Lenore Kasdorf',
#   'Yasuhiro Koume',
#   'Shin Kishida',
#   'Teddy Michaud',
#   'Bérénice Marlohe',
#   'Kim Boekhoorn',
#   'Stephan Evenblij',
#   'Madeleine Borg',
#   'Marlane Barnes',
#   'Jirô Hiratsuka',
#   'Cristian DeMeo',
#   'Simone Bailly',
#   'Vanessa Aspillaga',
#   'Lois Saunders',
#   'Nattakit Teachachevapong',
#   'Marina Aloupi',
#   'Jason Orr',
#   'Fujita Okamoto',
#   'Paola Lázaro',
#   'Rebeca Zimbrón',
#   'Olga Hamada',
#   'Marco Gerani',
#   'Cameron Brosky',
#   'Maggie Rose Lally',
#   'Sairaah Awasthi',
#   'Paul Cooke',
#   'Carol Ann Johnson',
#   'Joar Hennix Raukola',
#   'Darya Djavahery-Farsi',
#   'Erik Per Sullivan',
#   'Nello Scadato',
#   'Alain Dorval',
#   'Antonio Marziantonio',
#   'Brindabon Das',
#   'Heath Scarbrough',
#   'Lainie Frasier',
#   'Kelly Bailey',
#   'Martin Lawrence',
#   'Emma Samuelsson',
#   'Mihail Giannikakis',
#   'Chris MacKenzie',
#   'James Conklin',
#   'Dong-Won Gang',
#   'Angel Cruz',
#   'Saptha Giri',
#   'Sunny Kim',
#   'Luz María Collazo',
#   'Troy Daniel Smith',
#   'Max McCarthy',
#   'Mario Z.',
#   'Luis Antonio Espinosa',
#   'Gabrielle Rembert',
#   'Claude Smith',
#   'Valeriy Demchenko',
#   'Wes Sullivan',
#   'Jaimie Linn',
#   'Karenssa LeGear',
#   'Ahmed Fahmy',
#   'Pepe González Rubio',
#   'George Bunny',
#   'Peter Helens',
#   'Adam Fawns',
#   'Laurent Delahousse',
#   'Li Wei Chang',
#   'Steven Flynn',
#   'Kriz Chris Henri Harriz',
#   'Keith Knight',
#   'Christine Gauthier',
#   'Rita Deb Burman',
#   'María Casali',
#   'Tanjareen Thomas',
#   'Laura Colucci',
#   'Fabien Ara',
#   'Josefina Viton',
#   'Janina Traczykówna',
#   'Frank Gallegos',
#   'Avrielle Corti',
#   'Henry Woodward',
#   'Ferdinand Stahl',
#   'Marie-Élaine Berthiaume',
#   'Kumiko Tsuchiya',
#   'Rob Spendlove',
#   'Sophia Dawnay',
#   'Sebastién Reding',
#   'Gudrun Henricsson',
#   'Tex Morton',
#   'Paul Coates',
#   'Shenbaga',
#   'Shelley Regner',
#   'Keiko Niitaka',
#   'Luke McDonnell',
#   'Mackenzie Lush',
#   'Ernesto Baez',
#   'Madrid St. Angelo',
#   'Cassandra Jacobsen',
#   'Allen Robinson',
#   'Suraphun Kampharat',
#   'Fabian Jansen',
#   'Yoko Komatsu',
#   'Maxine Burth',
#   'Anne Loos',
#   'Pavala Shyamala',
#   'Werner Herzog',
#   'Yamaeh Allen',
#   'Steve Boozer',
#   'Megan Tracz',
#   'Nick Lauro Teresa',
#   'Jöns Andersson',
#   'Megan Topham',
#   'Shelley Kästner',
#   'Bruna Camerini',
#   'Joe Schenck',
#   'Tonpei Hidari',
#   'Ennio Colaianni',
#   'Sarah Fastenrath',
#   'Buddy Pepper',
#   'Mark Margason',
#   'Rachae Thomas',
#   'Edith Trane',
#   'Tony Owen',
#   'John F. Beach',
#   'Roy Campsall',
#   'Mehdi Das Neve',
#   'Alexa Khan',
#   'Dongyan Ma',
#   'Danay Garcia',
#   'Daniela Foà',
#   'Mark Ettlinger',
#   'Ángel de Andrés López',
#   'Aus Greidanus',
#   'Richard Cohee',
#   'Stephen Barrett',
#   'Halvor Halvorsen',
#   'Josele Román',
#   'Emil von Schönfels',
#   'James Aidan',
#   'Pradeep Machiraju',
#   'Mika',
#   'Werner Kolf',
#   'Mohamed Zouaoui',
#   'Gia Roinishvili',
#   'Matthew Moore',
#   'Tianyu Ma',
#   'Isabeau Dornevil',
#   'Googy Gress',
#   'Luke Hartney',
#   'Ian Lake',
#   'Lotta Forsberg',
#   'Phillip Rose',
#   'Darlene Craviotto',
#   'Maj Bockhahn Bjerregaard',
#   'Arshpreet Singh',
#   'Don Spruance',
#   'Steve Witting',
#   'Mahira Khan',
#   'Gene Raye Price',
#   'Tsutomu Itô',
#   'Tomonori Yazaki',
#   'Nick Carter',
#   'Robert Dean',
#   'Antonis Tempos',
#   'Garrett Gibbs',
#   'Jay Mannering',
#   'Bill Shaner',
#   'Claresie Mobley',
#   'Lukas Steltner',
#   'Sean Carmichael',
#   'Asmik Arakelyan',
#   'Pieter Van Hees',
#   'Sapir Kugman',
#   'Martin Drainville',
#   'Gracinha Leporace',
#   'Eunice Andrade',
#   'Sydney Wade',
#   'Darren Paul Kendrick',
#   'Sasha Crews',
#   'Chad Bartley',
#   'Lance Gross',
#   'Örjan Ramberg',
#   'Julia Putnam',
#   'Rolando Ravello',
#   'Bob Bragg',
#   'Giovanni Ferreri',
#   'Vince Puma',
#   'István Csorba',
#   'Deborah E. Graves',
#   'Robyn Shute',
#   'Pavel Doichev',
#   'Jay Ripley',
#   'Vibha Rani',
#   'Razeddin Sayyar',
#   'Adam J. Bernstein',
#   'David Walton',
#   'Marta Kozlova',
#   'Lisandra Payan',
#   'Andrew Rush',
#   'Erin Hunter',
#   'Michael Standing',
#   'Kess Bridge',
#   'Humberto Modenesi',
#   'Filip Bolluyt',
#   'Gerald Hurd',
#   'Wallace Langham',
#   'Graham Dickson',
#   'Ana Caetano',
#   'Theresa Maxwell Conover',
#   'Samuel Lee Guevara',
#   'Bob Odenkirk',
#   'Marcello Galdini',
#   'Joe Cipoletti',
#   'Richard Flato',
#   'Jitka Schneiderová',
#   'Jenny Goldstein',
#   'Jerzy Michal Bozyk',
#   'Garrett Gallego',
#   'Glen Robert Robillard',
#   'Suhas',
#   'Ophelia Lovibond',
#   'Louis-David Morasse',
#   'Ransford Doherty',
#   'Geoff Edholm',
#   'Carrie Westcott',
#   'Rachel Walters',
#   'Carole Farquhar',
#   'Jon Kellam',
#   'Zef Mosi',
#   'Zoe Boe',
#   'Elmo Redrico',
#   'Maria Saccenti',
#   'Cindy Ellis',
#   'Giorgio Comaschi',
#   'Clara Pontoppidan',
#   'Mihiro',
#   'Kurt Weinzierl',
#   'Berkan Sal',
#   'Jason Jack Edwards',
#   'Azad Khan',
#   'Tim Considine',
#   'Kristi Clainos',
#   'David Carren',
#   'Bastian Pastewka',
#   'Bia Gomes',
#   'Miriam S. Langmoen',
#   'Surasit Boonsak',
#   'P.M.H. Atwater',
#   'Christopher McLinden',
#   'Derek Chariton',
#   'Vidya Ully',
#   'Mohammad Taghi Kahnemoui',
#   'Mikhail Kremer',
#   'Austin Farnsworth',
#   'Tahir Adjaji',
#   'Julieta Vashakmadze',
#   'Lars Hanson',
#   'Marita Breuer',
#   'Richie Havens',
#   'Larry Wang Parrish',
#   'Sarah Lemp',
#   'Stephen Ohl',
#   'Djosef LaRoche',
#   'Gerard Pizzaras',
#   'Luciano Conti',
#   'Vlas Parlapanides',
#   'Marhoom Ahmad Bilal',
#   'Joey Naudic',
#   'Archibald L. Lyall',
#   'Dominique Leblanc',
#   'Lito',
#   'Sonika Chopra',
#   'Conrad Kemp',
#   'Alex King',
#   'Gina Riley',
#   'Himesh Patel',
#   'Tina Grimm',
#   'Louisa Moritz',
#   'Wladyslaw Brochwicz',
#   'Cem Özkirdeniz',
#   'Cinderella Gatcheco',
#   'Bernhard Conrad',
#   'Silvana Lipszyc',
#   'Cameran Surles',
#   'Josh Brown',
#   'Monique Lafond',
#   'Frances Rafferty',
#   'Edith Reiner',
#   'Sergei Pestrikov',
#   'Hao Ren',
#   'Gary Private',
#   'David Shabtai',
#   'Desireé Nash',
#   'Ian Iskandar Gouw',
#   'Jeffrey Novak',
#   'Shelby Deekins',
#   'Kaname Tsushima',
#   'Zhibing Liu',
#   'Ah-Mi Jung',
#   'Lisa Cash',
#   'Rosella Elmi',
#   'Johnny Vavouras',
#   'Carmen Santonja',
#   'Bonnie Law',
#   'Vyacheslav Rogovoy',
#   'Greg Norris',
#   'Glen Roberts',
#   'Cody Carroll',
#   'Teilor Grubbs',
#   'Denis Lill',
#   'José Mayer',
#   'April Tung',
#   'Acquah Dansoh',
#   'Letty Garris',
#   'Alex Ruiz',
#   'Marco Busciala',
#   'Carl Banks',
#   'Miguel Moreira',
#   'Jay William Thomas',
#   'Buddy Roosevelt',
#   'Ren Ishikawa',
#   'Paul Alan Walsh',
#   'Taner Birsel',
#   'Alexander Hutchinson',
#   'Pat Skipper',
#   'Dylan Ward',
#   'Bhilly San Roque',
#   'Maria Waldner',
#   'Leah Johnston',
#   'Patricia Eugenio',
#   'Myk Halstead',
#   'Janelle Hutchison',
#   'Robert C. Lee',
#   'Jaz Wilson',
#   'Rino Romano',
#   'Cameron Scott',
#   'Hayden Greene',
#   'Jennifer Sommerfeld',
#   'Heinz Ollesch',
#   'Valeria Lukyanova',
#   'Franki Boegeman',
#   'Souleymane Sow',
#   'Dan Puck',
#   'Aamir Yaseen',
#   'Ayse Sule Bilgiç',
#   'Monika Häckermann',
#   'Annika Persson',
#   'Dora Vila',
#   'Grant Jaeger',
#   'Mary Chen',
#   'Elizabeth Eaton',
#   'Lucrecia Federico',
#   'Staas Yudenko',
#   'Julie Faloux',
#   'Paul-Dolf Neis',
#   'Fabien Dupuis',
#   'Alexander Mulzac',
#   'Roger D.A. Davis',
#   "Gavan O'Connor-Duffy",
#   'Nichelle Nichols',
#   'Gustavo Laborde',
#   'Min-kwan Park',
#   'Ashley-Marie Zgabay',
#   'Vibeke Manniche',
#   'Arif Asçi',
#   'Brian Dixon',
#   'Mamatha Bhukya',
#   'Balachandran Chullikadu',
#   'Don Creery',
#   'Jeroen Planting',
#   'Matthew Settle',
#   'John Cothran',
#   'Jimmy Ray Pickens',
#   'Ashiq Ahmed',
#   'Francis McDonald',
#   'Gunnar Lindholm',
#   'Ximena Gonzalez-Rubio',
#   'Ant Canavan',
#   'Vittorio Farfan',
#   'Aisha Cerami',
#   'Filiz Akin',
#   'Garet Allen',
#   'Noah Gray-Cabey',
#   'Carmen Simone Birk',
#   'Sam Reid',
#   'Vo Vinh Phuc',
#   'Jeffrey Baxter',
#   'Talas Umurzakov',
#   'Raqual Curilem',
#   'Kanyapak Suworakood',
#   'Tian Hao',
#   'Thomas Durand',
#   'Miguel Cazorla',
#   'Jeremy Klavens',
#   'Aleksandr Alyoshkin',
#   'Joseph Russo',
#   'Dincer Isgel',
#   'Walter Jones',
#   'Miles Mussenden',
#   'Mayte Vilán',
#   'Boris Methner',
#   'Le Geng',
#   'Maria Wilczynska',
#   'George Edgley',
#   'Ashish Verma',
#   'Maged El-Kidwani',
#   'Joanna Jang',
#   'Mariya Ignatova',
#   'Zoltán Bukovszki',
#   'Françoise Jamet',
#   'Totch Brown',
#   'Matsunosuke Fukui',
#   'Mikael Brolin',
#   'Eunicia Jones',
#   'Arun Kadam',
#   'Volodomir Helias',
#   'Luca Lüdi',
#   'Miriam Lucia',
#   'Alberto Fernández',
#   'Min Zhang',
#   'Kevyn Connett',
#   'Keon Motakhaveri',
#   'Gerald Tyler',
#   'Judith Barsi',
#   'Jade Gialdini',
#   'Christopher Boyer',
#   'Dmitriy Solovev',
#   'Brennan Delaney',
#   'Saloni Umesh Burde',
#   'Jeff Jacobsen',
#   'Steven Fromholz',
#   'Karan Deol',
#   'Connie Bowman',
#   'Sora Ishii',
#   'Ellen Mirojnick',
#   'Kirstin Pierce',
#   'Coley Wallace',
#   'Kylie Slevin',
#   'Nancie Phillips',
#   'Ikuko Tani',
#   'Nastya Golubeva Carax',
#   'John Malkovich',
#   'Karina Kolokolchykova',
#   'Valeria Sachi',
#   'Sandra Rice',
#   'Jabba',
#   "Adrian O'Donnell",
#   'Nils Vogt',
#   'Katia Szechtman',
#   'James Ramsay',
#   'Billy Smith',
#   'Gardenia Polito',
#   'Josep Clarà',
#   'Cristina Bignardi',
#   'Mojiz Hasan',
#   'Mary Anderson',
#   'Andrew Kay',
#   'Esra Balikci',
#   'Giuseppe Aiello',
#   'Agne Grudyte',
#   'Rufus Fennell',
#   'Matt Dellapina',
#   'Dennis King',
#   'Giuseppe Colombo',
#   'Kamel Abdelli',
#   'Fei Wai Tse',
#   'Sammy Bangafaye',
#   'Kathryn Klvana',
#   'Brian Planut Alberti',
#   'Ajay Singh',
#   'Gordon Clifford',
#   'Sean Ryan McBride',
#   'Sheela Sharma',
#   'Claire Stansfield',
#   'Carles Velat',
#   'Roswita Schmidt',
#   'Shavinder Mahal',
#   'Arkadiusz Janiczek',
#   'Ruth Puebla',
#   'Vyong Nguyen',
#   'Mohamed Hicham',
#   'Zeena Bhatia',
#   'Fadi Haddadin',
#   'Charlotte Lowe',
#   'Charles St. Charles',
#   'Armando Romeo',
#   'Kôshirô Matsumoto',
#   'Brad Murphy',
#   'Manoushka Zeegelaar Breeveld',
#   'Tom Hiddleston',
#   'Seok-geun Jo',
#   'Esmay Lee Ann',
#   'Marika Matsumoto',
#   'Ferdousi Ahmed Lina',
#   'Masaharu Satô',
#   'Benchang You',
#   'Ilona Agathe Bastian',
#   'Pamela Serpe',
#   'Allan Meyette',
#   'Stephen Wu',
#   'Patsy Smart Darcus',
#   'Wayne Kryka',
#   'Jean Smart',
#   'Tôru Abe',
#   'Victoria Alcock',
#   'Chin Hsiao',
#   'Anna-Maija Ollikainen',
#   'Jonathan Annett Jr.',
#   'Andrés Crespo',
#   'Phil Tead',
#   'Sébastien Tessier',
#   'René Sánchez',
#   'Mason Davis',
#   'Tanie Kitabayashi',
#   'Kaspars Zvigulis',
#   'Joseph Booton',
#   'Kate Flannery',
#   'Camille Bardery',
#   'Amaury Delobre',
#   'Manie Malone',
#   'Emma Louise Saunders',
#   'Gabriel Signoret',
#   'Anders Hvidegaard',
#   'Joey Singer',
#   'Lawrence Kasanoff',
#   'Zafer Tawil',
#   'Deborah Sun',
#   ...},
#  366669)

# %% [markdown]
# ## Total number of languages

# %%
# This was carried out only on IMDB data set as there is no language column in Netflix dataset
list_unique_values_in_column(IMDBdata, 'language')
# Out:
# ({'Abkhazian',
#   'Aboriginal',
#   'Afrikaans',
#   'Akan',
#   'Albanian',
#   'Algonquin',
#   'American Sign Language',
#   'Amharic',
#   'Ancient (to 1453)',
#   'Apache languages',
#   'Arabic',
#   'Aragonese',
#   'Aramaic',
#   'Arapaho',
#   'Armenian',
#   'Aromanian',
#   'Assamese',
#   'Assyrian Neo-Aramaic',
#   'Athapascan languages',
#   'Australian Sign Language',
#   'Awadhi',
#   'Aymara',
#   'Azerbaijani',
#   'Bable',
#   'Balinese',
#   'Bambara',
#   'Basque',
#   'Belarusian',
#   'Bemba',
#   'Bengali',
#   'Berber languages',
#   'Bhojpuri',
#   'Bicolano',
#   'Bosnian',
#   'Brazilian Sign Language',
#   'Breton',
#   'British Sign Language',
#   'Bulgarian',
#   'Burmese',
#   'Cantonese',
#   'Catalan',
#   'Central American Indian languages',
#   'Chechen',
#   'Cheyenne',
#   'Chinese',
#   'Cornish',
#   'Corsican',
#   'Cree',
#   'Creek',
#   'Crimean Tatar',
#   'Croatian',
#   'Crow',
#   'Czech',
#   'Danish',
#   'Dari',
#   'Dinka',
#   'Dutch',
#   'Dyula',
#   'Dzongkha',
#   'Eastern Frisian',
#   'Egyptian (Ancient)',
#   'English',
#   'Esperanto',
#   'Estonian',
#   'Ewe',
#   'Faroese',
#   'Filipino',
#   'Finnish',
#   'Flemish',
#   'French',
#   'French Sign Language',
#   'Frisian',
#   'Fulah',
#   'Gallegan',
#   'Georgian',
#   'German',
#   'German Sign Language',
#   'Greek',
#   'Greenlandic',
#   'Guarani',
#   'Gujarati',
#   'Gumatj',
#   'Haida',
#   'Haitian',
#   'Hakka',
#   'Haryanvi',
#   'Hassanya',
#   'Hausa',
#   'Hawaiian',
#   'Hebrew',
#   'Himachali',
#   'Hindi',
#   'Hmong',
#   'Hokkien',
#   'Hopi',
#   'Hungarian',
#   'Ibo',
#   'Icelandic',
#   'Indian Sign Language',
#   'Indonesian',
#   'Inuktitut',
#   'Irish',
#   'Italian',
#   'Japanese',
#   'Japanese Sign Language',
#   'Kabuverdianu',
#   'Kabyle',
#   'Kannada',
#   'Kashmiri',
#   'Kazakh',
#   'Khmer',
#   'Kikuyu',
#   'Kinyarwanda',
#   'Kirghiz',
#   'Kirundi',
#   'Klingon',
#   'Konkani',
#   'Korean',
#   'Korean Sign Language',
#   'Kriolu',
#   'Kru',
#   'Kuna',
#   'Kurdish',
#   'Ladakhi',
#   'Ladino',
#   'Lao',
#   'Latin',
#   'Latvian',
#   'Lingala',
#   'Lithuanian',
#   'Low German',
#   'Luxembourgish',
#   'Macedonian',
#   'Malay',
#   'Malayalam',
#   'Malinka',
#   'Maltese',
#   'Mandarin',
#   'Mandingo',
#   'Manipuri',
#   'Maori',
#   'Mapudungun',
#   'Marathi',
#   'Mari',
#   'Maya',
#   'Mende',
#   'Micmac',
#   'Middle English',
#   'Min Nan',
#   'Minangkabau',
#   'Mirandese',
#   'Mixtec',
#   'Mohawk',
#   'Mongolian',
#   'Montagnais',
#   'More',
#   'Nahuatl',
#   'Nama',
#   'Navajo',
#   'Neapolitan',
#   'Nepali',
#   'None',
#   'Norse',
#   'North American Indian',
#   'Norwegian',
#   'Nyanja',
#   'Occitan',
#   'Ojibwa',
#   'Old',
#   'Old English',
#   'Oriya',
#   'Papiamento',
#   'Parsee',
#   'Pawnee',
#   'Persian',
#   'Peul',
#   'Polish',
#   'Polynesian',
#   'Portuguese',
#   'Punjabi',
#   'Purepecha',
#   'Pushto',
#   'Quechua',
#   'Quenya',
#   'Raeto-Romance',
#   'Rajasthani',
#   'Rhaetian',
#   'Romanian',
#   'Romany',
#   'Rotuman',
#   'Russian',
#   'Russian Sign Language',
#   'Ryukyuan',
#   'Saami',
#   'Samoan',
#   'Sanskrit',
#   'Sardinian',
#   'Scanian',
#   'Scots',
#   'Scottish Gaelic',
#   'Serbian',
#   'Serbo-Croatian',
#   'Shanghainese',
#   'Shanxi',
#   'Shona',
#   'Shoshoni',
#   'Sicilian',
#   'Sign Languages',
#   'Sindarin',
#   'Sindhi',
#   'Sinhalese',
#   'Sioux',
#   'Slovak',
#   'Slovenian',
#   'Somali',
#   'Songhay',
#   'Soninke',
#   'Southern Sotho',
#   'Spanish',
#   'Spanish Sign Language',
#   'Sranan',
#   'Swahili',
#   'Swedish',
#   'Swiss German',
#   'Syriac',
#   'Tagalog',
#   'Tajik',
#   'Tamashek',
#   'Tamil',
#   'Tarahumara',
#   'Tatar',
#   'Telugu',
#   'Teochew',
#   'Thai',
#   'Tibetan',
#   'Tigrigna',
#   'Tok Pisin',
#   'Tonga',
#   'Tswana',
#   'Tulu',
#   'Tupi',
#   'Turkish',
#   'Turkmen',
#   'Tzotzil',
#   'Uighur',
#   'Ukrainian',
#   'Ukrainian Sign Language',
#   'Ungwatsi',
#   'Urdu',
#   'Uzbek',
#   'Vietnamese',
#   'Visayan',
#   'Washoe',
#   'Wayuu',
#   'Welsh',
#   'Wolof',
#   'Xhosa',
#   'Yakut',
#   'Yiddish',
#   'Yoruba',
#   'Zulu'},
#  261)

# %% [markdown]
# ### List of languages for each top movie producing countries(USA, India, UK)

# %%
IMDBdata_USA = IMDBdata[IMDBdata['country'].str.contains('USA', regex = True)]
IMDBdata_USA[['country', 'language']]
# Out:
#            country language
# 0              USA     None
# 3              USA  English
# 5              USA  English
# 9      France, USA  English
# 17             USA  English
# ...            ...      ...
# 85812          USA  English
# 85830          USA  English
# 85837          USA  English
# 85838          USA  English
# 85839          USA  English
#
# [32145 rows x 2 columns]

# %%
list_unique_values_in_column(IMDBdata_USA, 'language')
# Out:
# ({'Aboriginal',
#   'Afrikaans',
#   'Akan',
#   'Albanian',
#   'Algonquin',
#   'American Sign Language',
#   'Amharic',
#   'Ancient (to 1453)',
#   'Apache languages',
#   'Arabic',
#   'Aramaic',
#   'Arapaho',
#   'Armenian',
#   'Aromanian',
#   'Assyrian Neo-Aramaic',
#   'Athapascan languages',
#   'Bambara',
#   'Basque',
#   'Belarusian',
#   'Bengali',
#   'Berber languages',
#   'Bosnian',
#   'Brazilian Sign Language',
#   'British Sign Language',
#   'Bulgarian',
#   'Burmese',
#   'Cantonese',
#   'Catalan',
#   'Central American Indian languages',
#   'Chechen',
#   'Cheyenne',
#   'Chinese',
#   'Cornish',
#   'Corsican',
#   'Cree',
#   'Creek',
#   'Croatian',
#   'Crow',
#   'Czech',
#   'Danish',
#   'Dari',
#   'Dutch',
#   'Egyptian (Ancient)',
#   'English',
#   'Esperanto',
#   'Estonian',
#   'Filipino',
#   'Finnish',
#   'Flemish',
#   'French',
#   'French Sign Language',
#   'Georgian',
#   'German',
#   'Greek',
#   'Greenlandic',
#   'Guarani',
#   'Gujarati',
#   'Haitian',
#   'Hakka',
#   'Hawaiian',
#   'Hebrew',
#   'Hindi',
#   'Hmong',
#   'Hokkien',
#   'Hopi',
#   'Hungarian',
#   'Ibo',
#   'Icelandic',
#   'Indian Sign Language',
#   'Indonesian',
#   'Inuktitut',
#   'Irish',
#   'Italian',
#   'Japanese',
#   'Japanese Sign Language',
#   'Kannada',
#   'Kazakh',
#   'Khmer',
#   'Kinyarwanda',
#   'Kirundi',
#   'Klingon',
#   'Korean',
#   'Kuna',
#   'Kurdish',
#   'Ladino',
#   'Lao',
#   'Latin',
#   'Latvian',
#   'Lingala',
#   'Lithuanian',
#   'Luxembourgish',
#   'Macedonian',
#   'Malay',
#   'Malayalam',
#   'Mandarin',
#   'Maori',
#   'Mapudungun',
#   'Maya',
#   'Mende',
#   'Middle English',
#   'Min Nan',
#   'Mohawk',
#   'Mongolian',
#   'Nahuatl',
#   'Nama',
#   'Navajo',
#   'Nepali',
#   'None',
#   'Norse',
#   'North American Indian',
#   'Norwegian',
#   'Nyanja',
#   'Old',
#   'Old English',
#   'Papiamento',
#   'Pawnee',
#   'Persian',
#   'Polish',
#   'Polynesian',
#   'Portuguese',
#   'Punjabi',
#   'Pushto',
#   'Quechua',
#   'Quenya',
#   'Rajasthani',
#   'Romanian',
#   'Romany',
#   'Rotuman',
#   'Russian',
#   'Saami',
#   'Samoan',
#   'Sanskrit',
#   'Scots',
#   'Scottish Gaelic',
#   'Serbian',
#   'Serbo-Croatian',
#   'Shanghainese',
#   'Shoshoni',
#   'Sicilian',
#   'Sign Languages',
#   'Sindarin',
#   'Sinhalese',
#   'Sioux',
#   'Slovak',
#   'Slovenian',
#   'Somali',
#   'Southern Sotho',
#   'Spanish',
#   'Spanish Sign Language',
#   'Swahili',
#   'Swedish',
#   'Swiss German',
#   'Syriac',
#   'Tagalog',
#   'Tamil',
#   'Telugu',
#   'Thai',
#   'Tibetan',
#   'Tok Pisin',
#   'Tonga',
#   'Tswana',
#   'Tupi',
#   'Turkish',
#   'Turkmen',
#   'Tzotzil',
#   'Ukrainian',
#   'Urdu',
#   'Uzbek',
#   'Vietnamese',
#   'Washoe',
#   'Welsh',
#   'Wolof',
#   'Xhosa',
#   'Yiddish',
#   'Yoruba',
#   'Zulu'},
#  176)

# %%
IMDBdata_India = IMDBdata[IMDBdata['country'].str.contains('India', regex = True)]
IMDBdata_India[['country', 'language']]
# Out:
#                              country        language
# 787               UK, India, Germany         English
# 2514                           India  Marathi, Hindi
# 5736                           India           Hindi
# 6072                           India           Hindi
# 6082                           India           Hindi
# ...                              ...             ...
# 85828                          India       Malayalam
# 85831  India, Netherlands, Singapore           Tamil
# 85843                          India           Tamil
# 85844                          India          Telugu
# 85847                          India       Malayalam
#
# [4705 rows x 2 columns]

# %%
list_unique_values_in_column(IMDBdata_India, 'language')
# Out:
# ({'Apache languages',
#   'Arabic',
#   'Assamese',
#   'Awadhi',
#   'Bengali',
#   'Bhojpuri',
#   'Cantonese',
#   'Catalan',
#   'Chinese',
#   'Czech',
#   'Dari',
#   'Dutch',
#   'English',
#   'Filipino',
#   'French',
#   'Georgian',
#   'German',
#   'Greek',
#   'Gujarati',
#   'Haryanvi',
#   'Hebrew',
#   'Himachali',
#   'Hindi',
#   'Hopi',
#   'Icelandic',
#   'Indian Sign Language',
#   'Indonesian',
#   'Italian',
#   'Japanese',
#   'Kannada',
#   'Kashmiri',
#   'Konkani',
#   'Korean',
#   'Ladakhi',
#   'Latin',
#   'Malay',
#   'Malayalam',
#   'Mandarin',
#   'Manipuri',
#   'Marathi',
#   'Mongolian',
#   'Nepali',
#   'None',
#   'Oriya',
#   'Parsee',
#   'Persian',
#   'Polish',
#   'Portuguese',
#   'Punjabi',
#   'Rajasthani',
#   'Romanian',
#   'Russian',
#   'Sanskrit',
#   'Sindhi',
#   'Spanish',
#   'Swahili',
#   'Swedish',
#   'Tamil',
#   'Telugu',
#   'Thai',
#   'Tibetan',
#   'Tulu',
#   'Turkish',
#   'Ukrainian',
#   'Urdu',
#   'Uzbek'},
#  66)

# %%
IMDBdata_UK = IMDBdata[IMDBdata['country'].str.contains('UK', regex = True)]
IMDBdata_UK[['country', 'language']]
# Out:
#            country                          language
# 315             UK                           English
# 393             UK                           English
# 437    UK, Germany                           English
# 449    UK, Germany                           English
# 499             UK                              None
# ...            ...                               ...
# 85770           UK                           English
# 85772           UK                           English
# 85784           UK                           English
# 85827           UK                           English
# 85846           UK  English, Polish, Russian, German
#
# [7130 rows x 2 columns]

# %%
list_unique_values_in_column(IMDBdata_UK, 'language')
# Out:
# ({'Aboriginal',
#   'Afrikaans',
#   'Akan',
#   'Albanian',
#   'Algonquin',
#   'American Sign Language',
#   'Amharic',
#   'Ancient (to 1453)',
#   'Apache languages',
#   'Arabic',
#   'Armenian',
#   'Assamese',
#   'Athapascan languages',
#   'Azerbaijani',
#   'Basque',
#   'Bemba',
#   'Bengali',
#   'Bosnian',
#   'Brazilian Sign Language',
#   'Breton',
#   'British Sign Language',
#   'Bulgarian',
#   'Burmese',
#   'Cantonese',
#   'Catalan',
#   'Chinese',
#   'Corsican',
#   'Croatian',
#   'Czech',
#   'Danish',
#   'Dari',
#   'Dutch',
#   'Dzongkha',
#   'Egyptian (Ancient)',
#   'English',
#   'Esperanto',
#   'Estonian',
#   'Filipino',
#   'Finnish',
#   'French',
#   'French Sign Language',
#   'Georgian',
#   'German',
#   'Greek',
#   'Greenlandic',
#   'Guarani',
#   'Gujarati',
#   'Hawaiian',
#   'Hebrew',
#   'Hindi',
#   'Hungarian',
#   'Icelandic',
#   'Indonesian',
#   'Inuktitut',
#   'Irish',
#   'Italian',
#   'Japanese',
#   'Kashmiri',
#   'Khmer',
#   'Kinyarwanda',
#   'Klingon',
#   'Korean',
#   'Kurdish',
#   'Lao',
#   'Latin',
#   'Latvian',
#   'Lingala',
#   'Lithuanian',
#   'Luxembourgish',
#   'Macedonian',
#   'Malay',
#   'Malayalam',
#   'Maltese',
#   'Mandarin',
#   'Maori',
#   'Mapudungun',
#   'Maya',
#   'Mende',
#   'Min Nan',
#   'Mohawk',
#   'More',
#   'Nepali',
#   'None',
#   'Norse',
#   'North American Indian',
#   'Norwegian',
#   'Nyanja',
#   'Ojibwa',
#   'Old',
#   'Old English',
#   'Pawnee',
#   'Persian',
#   'Polish',
#   'Portuguese',
#   'Punjabi',
#   'Pushto',
#   'Quechua',
#   'Rajasthani',
#   'Romanian',
#   'Romany',
#   'Russian',
#   'Saami',
#   'Sanskrit',
#   'Scots',
#   'Scottish Gaelic',
#   'Serbian',
#   'Serbo-Croatian',
#   'Shanghainese',
#   'Shoshoni',
#   'Sign Languages',
#   'Sindarin',
#   'Sindhi',
#   'Sioux',
#   'Slovak',
#   'Slovenian',
#   'Somali',
#   'Southern Sotho',
#   'Spanish',
#   'Swahili',
#   'Swedish',
#   'Swiss German',
#   'Tagalog',
#   'Tamil',
#   'Tarahumara',
#   'Thai',
#   'Tibetan',
#   'Tonga',
#   'Tswana',
#   'Turkish',
#   'Turkmen',
#   'Ukrainian',
#   'Ungwatsi',
#   'Urdu',
#   'Vietnamese',
#   'Washoe',
#   'Welsh',
#   'Wolof',
#   'Xhosa',
#   'Yiddish',
#   'Zulu'},
#  140)

# %% [markdown]
# ## Insight into avg_vote in IMDB data

# %%
plt.figure(figsize = (8, 6))
sns.histplot(IMDBdata.avg_vote, bins = 10)
plt.show()

# %% [markdown]
# ## Insight into reviews_from_users in IMDB data

# %%
IMDBdata.reviews_from_users.describe()
# Out:
# count    72043.000000
# mean        49.213262
# std        185.479430
# min          1.000000
# 25%          4.000000
# 50%         10.000000
# 75%         29.000000
# max      10472.000000
# Name: reviews_from_users, dtype: float64

# %%
IMDBdata.reviews_from_users.value_counts()
# Out:
# 1.0       6126
# 2.0       5541
# 3.0       4716
# 4.0       4074
# 5.0       3535
#           ...
# 888.0        1
# 1847.0       1
# 526.0        1
# 691.0        1
# 1210.0       1
# Name: reviews_from_users, Length: 1211, dtype: int64

# %%
IMDBdata2 = IMDBdata[IMDBdata.reviews_from_users < 1000]

# %%
IMDBdata2.shape
# Out:
# (71660, 15)

# %%
IMDBdata3 = IMDBdata[IMDBdata.reviews_from_users < 800]

# %%
IMDBdata3.shape
# Out:
# (71453, 15)

# %%
IMDBdata4 = IMDBdata[IMDBdata.reviews_from_users < 600]

# %%
IMDBdata4.shape
# Out:
# (71089, 15)

# %%
IMDBdata5 = IMDBdata[IMDBdata.reviews_from_users < 500]

# %%
IMDBdata5.shape
# Out:
# (70817, 15)

# %%
plt.figure(figsize = (18, 6))
sns.histplot(IMDBdata5.reviews_from_users, bins = 100 )
plt.show()

# %% [markdown]
# ## Insight into votes in IMDB data

# %%
IMDBdata.votes.describe()
# Out:
# count    7.204300e+04
# mean     1.120770e+04
# std      5.828924e+04
# min      9.900000e+01
# 25%      2.420000e+02
# 50%      6.170000e+02
# 75%      2.425000e+03
# max      2.278845e+06
# Name: votes, dtype: float64

# %%
IMDBdata.votes.value_counts()
# Out:
# 105      210
# 101      198
# 109      191
# 113      188
# 112      188
#         ...
# 20368      1
# 3992       1
# 6043       1
# 12188      1
# 4094       1
# Name: votes, Length: 14860, dtype: int64

# %%
IMDB_300 = IMDBdata[IMDBdata.votes < 300]
IMDB_300.shape
# Out:
# (22340, 15)

# %%
plt.figure(figsize = (15, 6))
sns.histplot(IMDB_300.votes, bins = 100)
plt.show()

# %% [markdown]
# # Part-III: Comparision between two datasets

# %%
# Country column
plt.figure(figsize = (30, 6))
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.bar(x = column_details(Kaggledata, 'country')[1].index[:20], height = column_details(Kaggledata, 'country')[1].values[:20])
plt.xticks(rotation = 90)
plt.xlabel('Country')
plt.ylabel('Number of movies')
plt.title("Country vs. Number of movies (Kaggle Dataset), top 20 countries")
fig.subplots_adjust(wspace = 2)


ax2.bar(x = column_details(IMDBdata, 'country')[1].index[:20], height = column_details(IMDBdata, 'country')[1].values[:20])
plt.xticks(rotation = 90)
plt.xlabel('Country')
plt.ylabel('Number of movies')
plt.title("Country vs. Number of movies (IMDB Dataset), top 20 countries")
plt.tight_layout()
plt.show()

# %%
# Movie duration 
print("Maximum movie length listed in Kaggle datset:", Kaggledata.duration_min.max())
print("Minimum movie length listed in Kaggle dataset:", Kaggledata.duration_min.min())
print("Maximum movie length listed in IMDB datset:", IMDBdata.duration.max())
print("Minimum movie length listed in IMDB dataset:", IMDBdata.duration.min())


print("\nMost of the movies are of length (as listed in Kaggle Dataset):", Kaggledata.duration_min.value_counts().idxmax())
print("Most of the movies are of length (as listed in IMDB Dataset):", IMDBdata.duration.value_counts().idxmax())
# Out:
# Maximum movie length listed in Kaggle datset: 312
# Minimum movie length listed in Kaggle dataset: 8
# Maximum movie length listed in IMDB datset: 808
# Minimum movie length listed in IMDB dataset: 41
#
# Most of the movies are of length (as listed in Kaggle Dataset): 93
# Most of the movies are of length (as listed in IMDB Dataset): 90

# %%
# movie Release year
print("Maximum number of movies relased  in the year as listed in Kaggle datset:", Kaggledata.release_year.value_counts().idxmax())

print("Maximum number of movies released  in the year as listed in IMDB datset:", IMDBdata.year.value_counts().idxmax())
# Out:
# Maximum number of movies relased  in the year as listed in Kaggle datset: 2017
# Maximum number of movies released  in the year as listed in IMDB datset: 2017

# %% [markdown]
# # Part-IV

# %%
Kaggledata.columns
# Out:
# Index(['show_id', 'type', 'title', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration_min', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# **There is no need of the "show_id", "type" and "rating" columns, hence these are dropped from the dataset.**

# %%
Kaggledata.drop(columns = ['show_id', 'type', 'rating'], inplace = True)

# %%
IMDBdata.columns
# Out:
# Index(['imdb_title_id', 'original_title', 'year', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'reviews_from_users'],
#       dtype='object')

# %% [markdown]
# **The 'imdb_title_id' column seems to be not useful for further analysis or building Machine Learning model. Hence this columns needs to be dropped from the dataset.**

# %%
IMDBdata.drop(columns = ['imdb_title_id'], inplace = True )

# %% [markdown]
# **In both datasets, there are some columns meaning same, whereas their names are different. So for further investigation, they were named same.**

# %%
IMDBdata.rename(columns = {'original_title': 'title', 'year': 'release_year', 'duration': 'duration_min'}, inplace = True)

# %%
Kaggledata.dropna(inplace = True)
Kaggledata.shape
# Out:
# (4761, 8)

# %%
IMDBdata.dropna(inplace = True)
IMDBdata.shape
# Out:
# (72043, 14)

# %% [markdown]
# ## Relationship among differnet numerical columns in the dataset

# %% [markdown]
# **There are few numerical columns in the IMDB dataset. Hence let us investigation into the relationship among them plotting the pairplots.**

# %%
sns.pairplot(IMDBdata)
plt.show()

# %%
# Save both datsets
Kaggledata.to_csv("clean_datafiles/Kaggledata_ready_for_preprocessing.csv")
IMDBdata.to_csv("clean_datafiles/IMDBdata_ready_for_preprocessing.csv")

# %% [markdown]
# # Summary

# %% [markdown]
# We used two movie datasets : Kaggle dataset (named Netflix) and IMDB dataset (named IMDBdata). The Kaggle dataset is smaller one with 4761 rows while IMDB dataset large with 72043 rows.<br><br>
# Detail investigations into each column of both datasets was carried out and following conclusions were drwan:<br>
# * Both datasets show USA ranked Number One in movie production, while India ranked Second followed by United Kingdom in Third place.<br><br>
# * These are three movie production companies ranking as follows.<br>
# Metro-Goldwyn-Mayer (MGM)    1267<br>
# Warner Bros.                 1143<br>
# Columbia Pictures             909<br><br>
# * In USA top movie production company is: Metro-Goldwyn-Mayer <br>
# In India top movie production company is: NH Studioz <br>
# In UK top movie production company is: The Rank Organisation <br><br>
# * Both datasets show most of the movies are of length ~100 mins.<br><br>
